# %%
import csv

l = []

with open(r"C:\Users\Акмира\OneDrive\Документы\GitHub\ICT_2022\practice7\list_symbols_euronext.csv", 'r') as file:
    csvfile1 = csv.reader(file)
    for i in csvfile1:
        l += i

with open(r"C:\Users\Акмира\OneDrive\Документы\GitHub\ICT_2022\practice7\list_symbols_US.csv", 'r') as file:
    csvfile2 = csv.reader(file)
    for i in csvfile2:
        l += i

print(len(l))
# Out:
# 10045

# %%
import pandas as pd
import requests

for i in range(10):
    try:
        url = "https://query1.finance.yahoo.com/v7/finance/download/"+l[i]+"?period1=0&period2=1661904000&interval=1d&events=history&includeAdjustedClose=true"
        print(pd.read_csv(url))
    except:
        pass
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2006-02-08  23.299999  23.299999  23.299999  23.299999  20.706814
# 1     2006-02-09  17.950001  17.950001  17.950001  17.950001  15.952249
# 2     2006-02-10  16.990000  16.990000  16.990000  16.990000  15.099088
# 3     2006-02-13  18.059999  18.059999  18.059999  18.059999  16.050003
# 4     2006-02-14  19.000000  19.000000  19.000000  19.000000  16.885384
# ...          ...        ...        ...        ...        ...        ...
# 4231  2022-08-24  27.400000  27.400000  25.900000  25.900000  25.900000
# 4232  2022-08-25  25.900000  25.900000  25.900000  25.900000  25.900000
# 4233  2022-08-26  25.900000  25.900000  25.900000  25.900000  25.900000
# 4234  2022-08-29  25.900000  25.900000  25.900000  25.900000  25.900000
# 4235  2022-08-30  25.900000  25.900000  25.900000  25.900000  25.900000
#
#         Volume
# 0          0.0
# 1     177800.0
# 2      65600.0
# 3      38200.0
# 4      23200.0
# ...

# %%
import pandas as pd
import requests

dff = []
for i in range(10):
    try:
        url = "https://query1.finance.yahoo.com/v7/finance/download/"+l[i]+"?period1=0&period2=1661904000&interval=1d&events=history&includeAdjustedClose=true"
        df = pd.read_csv(url)
        df['Name'] = l[i]
        print(df)
    except:
        pass
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2006-02-08  23.299999  23.299999  23.299999  23.299999  20.706814
# 1     2006-02-09  17.950001  17.950001  17.950001  17.950001  15.952243
# 2     2006-02-10  16.990000  16.990000  16.990000  16.990000  15.099091
# 3     2006-02-13  18.059999  18.059999  18.059999  18.059999  16.050003
# 4     2006-02-14  19.000000  19.000000  19.000000  19.000000  16.885386
# ...          ...        ...        ...        ...        ...        ...
# 4231  2022-08-24  27.400000  27.400000  25.900000  25.900000  25.900000
# 4232  2022-08-25  25.900000  25.900000  25.900000  25.900000  25.900000
# 4233  2022-08-26  25.900000  25.900000  25.900000  25.900000  25.900000
# 4234  2022-08-29  25.900000  25.900000  25.900000  25.900000  25.900000
# 4235  2022-08-30  25.900000  25.900000  25.900000  25.900000  25.900000
#
#         Volume      Name
# 0          0.0  ALMIL.PA
# 1     177800.0  ALMIL.PA
# ...

# %%
import pandas as pd
import requests

dff = []
for i in range(10):
    try:
        url = "https://query1.finance.yahoo.com/v7/finance/download/"+l[i]+"?period1=0&period2=1661904000&interval=1d&events=history&includeAdjustedClose=true"
        df = pd.read_csv(url)
        df['Name'] = l[i]
        dff.append(df)
        # print(df)
    except:
        pass

print(pd.concat(dff, ignore_index=True))

# df.to_csv(r"C:\Users\Акмира\OneDrive\Документы\GitHub\ICT_2022\lecture7\mycsv.csv")
# df.to_parquet(r"C:\Users\Акмира\OneDrive\Документы\GitHub\ICT_2022\practice7\mycsv_par.parquet")
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# 0      2006-02-08  23.299999  23.299999  23.299999  23.299999  20.706816
# 1      2006-02-09  17.950001  17.950001  17.950001  17.950001  15.952247
# 2      2006-02-10  16.990000  16.990000  16.990000  16.990000  15.099088
# 3      2006-02-13  18.059999  18.059999  18.059999  18.059999  16.050003
# 4      2006-02-14  19.000000  19.000000  19.000000  19.000000  16.885387
# ...           ...        ...        ...        ...        ...        ...
# 30232  2022-08-24   7.500000   7.500000   7.280000   7.380000   7.380000
# 30233  2022-08-25   8.280000   9.400000   8.260000   8.800000   8.800000
# 30234  2022-08-26   8.640000   9.070000   8.570000   8.910000   8.910000
# 30235  2022-08-29   8.720000   9.045000   8.600000   8.870000   8.870000
# 30236  2022-08-30   8.950000   9.095000   8.860000   9.025000   9.025000
#
#          Volume      Name
# 0           0.0  ALMIL.PA
# 1      177800.0  ALMIL.PA
# ...
