# %%
import requests

url = "https://translate.yandex.ru/"

resp = requests.get(url)
print(resp.content)
# Out:
# b'<!DOCTYPE html>\n<html>\n\n<head>\n    <title>403</title>\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n    \n    \n    \n<style>\n    body {\n        font-family: Arial, sans-serif;\n        margin: 0;\n        padding: 0;\n        color: #000;\n        background-color: #fff;\n    }\n\n    body .content {\n        padding: 15px 70px 80px;\n        font-size: 15px;\n        line-height: 20px;\n        margin: 20px 0 30px;\n    }\n\n    .header {\n        height: 48px;\n    }\n\n    .header__logo {\n        display: inline-block;\n        overflow: hidden;\n        min-width: 130px;\n        height: 36px;\n        white-space: nowrap;\n        text-indent: 100%;\n        background-repeat: no-repeat;\n        background-position: center center;\n        background-image: url(\'data:image/svg+xml;base64,...\');\n        background-size: contain;\n        margin-left: 5px;\n        margin-right: 5px;\n    }\n\n    .header__code {\n        font-size: 32px;\n        display: inline-block;\n        overflow: hidden;\n        width: 76px;\n        text-align: center;\n        color: #fff;\n        background-color: #999;\n    }\n\n    .content__h1 {\n        font-size: 21px;\n        font-weight: 400;\n    }\n\n    .footer {\n        line-height: 30px;\n        height: 30px;\n        padding: 0 25px;\n        border-top: 1px solid #eee;\n    }\n\n    .footer__copyright {\n        font-size: 13px;\n    }\n\n    .link {\n        color: #44b;\n    }\n\n    .link:hover {\n        color: #e00;\n    }\n</style>\n\n</head>\n\n<body>\n    \n    <div class=\'header\'>\n        <a class="header__logo" href="https://www.yandex.ru">Yandex</a>\n        <div class=\'header__code\'>403</div>\n    </div>\n    <div class=\'content\'>\n        \n            \n    <h1 class="content__h1">\xd0\x94\xd0\xbe\xd1\x81\xd1\x82\xd1\x83\xd0\xbf \xd0\xba&nbsp;\xd0\xbd\xd0\xb0\xd1\x88\xd0\xb5\xd0\xbc\xd1\x83 \xd1\x81\xd0\xb5\xd1\x80\xd0\xb2\xd0\xb8\xd1\x81\xd1\x83 \xd0\xb2\xd1\x80\xd0\xb5\xd0\xbc\xd0\xb5\xd0\xbd\xd0\xbd\xd0\xbe \xd0\xb7\xd0\xb0\xd0\xbf\xd1\x80\xd0\xb5\xd1\x89\xd1\x91\xd0\xbd!</h1><p>\xd0\x92\xd0\xbe\xd0\xb7\xd0\xbc\xd0\xbe\xd0\xb6\xd0\xbd\xd0\xbe, \xd0\xb2\xd0\xb0\xd1\x88 \xd0\xba\xd0\xbe\xd0\xbc\xd0\xbf\xd1\x8c\xd1\x8e\xd1\x82\xd0\xb5\xd1\x80 \xd0\xb7\xd0\xb0\xd1\x80\xd0\xb0\xd0\xb6\xd1\x91\xd0\xbd \xd0\xb2\xd1\x80\xd0\xb5\xd0\xb4\xd0\xbe\xd0\xbd\xd0\xbe\xd1\x81\xd0\xbd\xd0\xbe\xd0\xb9 \xd0\xbf\xd1\x80\xd0\xbe\xd0\xb3\xd1\x80\xd0\xb0\xd0\xbc\xd0\xbc\xd0\xbe\xd0\xb9, \xd0\xba\xd0\xbe\xd1\x82\xd0\xbe\xd1\x80\xd0\xb0\xd1\x8f \xd0\xb0
meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no,shrink-to-fit=no,viewport-fit=cover" name="viewport"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="Telegram Web" name="mobile-web-app-title"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="Telegram Web" name="apple-mobile-web-app-title"/>
#   <meta content="Telegram Web" name="application-name"/>
#   <meta content="#2b5797" name="msapplication-TileColor"/>
#   <meta content="./browserconfig.xml" name="msapplication-config"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="noindex" name="robots"/>
#   <meta content="notranslate" name="google"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://web.telegram.org/z/" property="og:url"/>
#   <meta content="Telegram Web" property="og:title"/>
#   <meta content="Telegram is a cloud-based mobile and desktop messaging app with a focus on security and speed." property="og:description"/>
#   <meta content="./icon-192x192.png" property="og:image"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="https://web.telegram.org/z/" property="twitter:url"/>
#   <meta content="Telegram Web" property="twitter:title"/>
#   <meta content="Telegram is a cloud-based mobile and desktop messaging app with a focus on security and speed." property="twitter:description"/>
#   <meta content="./icon-192x192.png" property="twitter:image"/>
#   <link href="./apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="./favicon.svg" rel="icon" type="image/svg+xml"/>
#   <link href="./favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="./favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="./icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="./favicon.ico" rel="alternate icon" type="image/x-icon"/>
#   <link href="./site.webmanifest" id="the-manifest-placeholder" rel="manifest">
#    <script defer="defer" src="main.a57772ba5c16bceadd35.js">
#    </script>
#    <link href="main.a9e40ce9890cd96161e6.css" rel="stylesheet"/>
#   </link>
#  </head>
#  <body>
#   <noscript>
#    <video autoplay="" class="nojs-video" disablepictureinpicture="" loop="" muted="" playsinline="" src="./nojs.mp4">
#    </video>
#    <h1>
#     Telegram Web
#    </h1>
#    <p>
#     Please, enable JavaScript to open the app.
#    </p>
#   </noscript>
#   <div id="root">
#   </div>
#   <div id="portals">
#   </div>
#  </body>
# </html>

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191"
headers = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36"}

resp = requests.get(url, headers = headers)

soup = BeautifulSoup(resp.content)

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="accuweather" lang="en-us">
#  <head>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8">
#    <link href="https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191" rel="canonical"/>
#    <title>
#     Almaty, Almaty, Kazakhstan Today, Tonight &amp; Tomorrow's Weather Forecast | AccuWeather
#    </title>
#    <meta content="Get the forecast for today, tonight &amp; tomorrow's weather for Almaty, Almaty, Kazakhstan. Hi/Low, RealFeel®, precip, radar, &amp; everything you need to be ready for the day, commute, and weekend!" name="Description"/>
#    <meta content="width=device-width, initial-scale=1.0" name="viewport">
#     <meta content="origin" name="referrer"/>
#     <meta content="AccuWeather" property="fb:profile_id"/>
#     <meta content="132437483467956" property="fb:app_id"/>
#     <meta content="71781612888" property="fb:pages"/>
#     <meta content="website" property="og:type"/>
#     <meta content="Almaty, Almaty, Kazakhstan Today, Tonight &amp; Tomorrow's Weather Forecast | AccuWeather" property="og:title"/>
#     <meta content="Get the forecast for today, tonight &amp; tomorrow's weather for Almaty, Almaty, Kazakhstan. Hi/Low, RealFeel®, precip, radar, &amp; everything you need to be ready for the day, commute, and weekend!" property="og:description"/>
#     <meta content="AccuWeather" property="site_name"/>
#     <meta content="https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191" property="og:url"/>
#     <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image"/>
#     <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image:url"/>
#     <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image:secure_url"/>
#     <meta content="https://twitter.com/accuweather" name="twitter:site"/>
#     <meta content="summary" name="twitter:card"/>
#     <meta content="Almaty, Almaty, Kazakhstan Today, Tonight &amp; Tomorrow's Weather Forecast | AccuWeather" name="twitter:text:title"/>
#     <meta content="Almaty, Almaty, Kazakhstan Today, Tonight &amp; Tomorrow's Weather Forecast | AccuWeather" name="twitter:title"/>
#     <meta content="Get the forecast for today, tonight &amp; tomorrow's weather for Almaty, Almaty, Kazakhstan. Hi/Low, RealFeel®, precip, radar, &amp; everything you need to be ready for the day, commute, and weekend!" name="twitter:description"/>
#     <meta content="https://twitter.com/accuweather" name="twitter:site:id"/>
#     <meta content="https://twitter.com/accuweather" name="twitter:creator"/>
#     <meta content="https://twitter.com/accuweather" name="twitter:creator:id"/>
#     <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" name="twitter:image"/>
#     <meta content="AccuWeather: Weather Tracker" name="twitter:app:name:iphone"/>
#     <meta content="U7D6TVQ9TT.com.yourcompany.TestWithCustomTabs" name="twitter:app:id:iphone"/>
#     <meta content="https://apps.apple.com/US/app/id300048137?mt=8" name="twitter:app:url:iphone"/>
#     <meta content="AccuWeather: Weather Tracker" name="twitter:app:name:ipad"/>
#     <meta content="U7D6TVQ9TT.com.yourcompany.TestWithCustomTabs" name="twitter:app:id:ipad"/>
#     <meta content="https://apps.apple.com/US/app/id300048137?mt=8" name="twitter:app:url:ipad"/>
#     <meta content="AccuWeather Winter weather alerts &amp; forecast radar" name="twitter:app:name:googleplay"/>
#     <meta content="com.accuweather.android" name="twitter:app:id:googleplay"/>
#     <meta content="https://play.google.com/store/apps/details?id=com.accuweather.android" name="twitter:app:url:googleplay"/>
#     <script type="application/ld+json">
#      {
# 	"@context": "https://schema.org",
# 	"@type": "Organization",
# 	"name": "AccuWeather",
# 	"url": "https://www.accuweather.com",
# 	"sameAs": [
# 		"https://www.facebook.com/AccuWeather",
# 		"https://twitter.com/BreakingWeather",
# 		"https://www.instagram.com/accuweather",
# 		"https://www.youtube.com/user/accuweather"
#   ]
# }
#     </script>
#     <script type="application/ld+json">
#      {
# 		"@context": "https://schema.org",
# 		"@type": "Place",
# 		"address": {
# 			"@type": "PostalAddress",
# 			"addressLocality": "Almaty, Kazakhstan",
# 			"addressRegion": "Almaty",
# 			"postalCode": ""
# 		},
# 		"geo": {
# 			"@type": "GeoCoordinates",
# 			"latitude": "43.255",
# 			"longitude": "76.913",
# 			"addressCountry": "KZ",
# 			"postalCode": ""
# 		},
# 		"name": "Almaty, Almaty, Kazakhstan"
# 	}
#     </script>
#     <script type="application/ld+json">
#      {
# 	"@context": "https://schema.org",
# 	"@type": "WebSite",
# 	"mainEntityOfPage": {
# 		"@type": "WebPage",
# 		"@id": "https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191",
# 		"relatedLink": "https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191"
# 	},
# 	"image": {
# 		"@type": "ImageObject",
# 		"url": "https://www.accuweather.com/images/logos/accuweather-dark.png",
# 		"height": 172,
# 		"width": 1200
# 	},
# 	"author": {
# 		"@type": "Person",
# 		"name": "AccuWeather"
# 	},
# 	"publisher": {
# 		"@context": "https://schema.org",
# 		"@type": "Organization",
# 		"name": "AccuWeather",
# 		"url": "https://www.accuweather.com/",
# 		"logo": {
# 			"@type": "ImageObject",
# 			"url": "https://www.accuweather.com/images/logos/accuweather-dark-small.png",
# 			"width": 163,
# 			"height": 23
# 		}
# 	},
# 	"url": "https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191",
# 	"headline": "Almaty, Almaty, Kazakhstan Today, Tonight &amp; Tomorrow&#x27;s Weather Forecast",
# 	"description": "Get the forecast for today, tonight &amp; tomorrow&#x27;s weather for Almaty, Almaty, Kazakhstan. Hi/Low, RealFeel&#xAE;, precip, radar, &amp; everything you need to be ready for the day, commute, and weekend!"
# }
#     </script>
#     <style>
#      @font-face {
# 			font-family: 'Solis';
# 			src: url('https://www.awxcdn.com/adc-assets/fonts/solis-regular.woff') format('woff');
# 			font-weight: 400;
# 			font-style: normal;
# 			font-display: swap;
# 		}
#     </style>
#     <link href="https://www.awxcdn.com/adc-assets/bundles/city.three-day-desktop.c614ac96eb1238e59390.css" rel="stylesheet"/>
#     <link href="https://www.awxcdn.com/adc-assets/bundles/5.d2e76f9abbb143203208.css" rel="stylesheet"/>
#     <script>
#      var globalAdConfig = {"prebidTimeout":1500,"awxTimeout":1000,"ortbSite":{"categories":["IAB3","IAB7","IAB8","IAB10","IAB12","IAB15","IAB17","IAB20"],"content":{"title":"","url":"","categories":["IAB12-3","IAB15-10"],"productQuality":"1","context":"5","keywords":"","sourceRelationship":1,"language":"","data":{"name":"accuweather.com","extensions":{"segtax":"4"},"segments":[{"name":"id","value":""}]}},"domain":"www.accuweather.com","keywords":"","name":"AccuWeather","privacyPolicy":1,"mobile":1,"pageCategories":["IAB12-3","IAB15-10"],"publisher":{"name":"AccuWeather","domain":"www.accuweather.com","categories":["IAB3","IAB7","IAB8","IAB10","IAB12","IAB15","IAB17","IAB20"]},"sectionCategories":[""]},"enableSingleRequest":true,"lazyLoadingData":"{}","skipGoogleAdManager":true,"prebidBundleId":"a","testVariant":""};
# var isPrebidDisabled = false;
# var adExclusion = null;
# var botDetected = 0;
# var adInfo = {"fdate":"20221012","lang":"en-us","ut":"1","advelvet":"18","bot":"0","pgview":"1","partner":"accuweather","ufdb":"UKAA","city":"Almaty","country":"KZ","state":"ALA","dma":null,"key":"222191","browser":"chrome","connection":"_vhigh_5000","cuhd":"18","cuhi":"61","cuuv":"3","cuwd":"4","cuwx":"1","realfeel":"70,a75,b75,c75,d75","cuaq":"2","fc1hi":"74","fc1lo":"45","fc1wx":"1","lfscategory":"heat","lfsday":"5","lfsseverity":"7","lfs":"7_heat_5","pt":"0","userid":"missing","userid3p":"active"};
# var adPageInfo = {category:'weather',template:'local_home'};
# var partnerCode = 'accuweather';
# var countryCode = 'kz';
# var networkType = 'Unknown';
# var throughput = 'vhigh';
# if (window.Raine) {
# 	window.Raine.pageLoading({
# 		serverRenderTime: window.raineConfig.serverRenderTime,
# 		pageName: window.adPageInfo.template,
# 		pageGroup: window.adPageInfo.category,
# 		mock: false,
# 		testGroup: '',
# 		networkType: networkType,
# 		throughput: throughput,
# 		countryCode: countryCode,
# 		partnerCode: partnerCode,
# 		botDetected: botDetected,
# 	});
# }
#     </script>
#     <script>
#      var isPwaActive = false;
# 		var serverAdsOnPageLite = {"top":{"config":{"responsiveSizes":[{"window":[1024,0],"sizes":["fluid",[980,120],[980,90],[970,250],[970,90],[950,90],[930,180],[750,100],[750,300],[750,200],[728,90]]},{"window":[768,0],"sizes":["fluid",[728,90],[468,60],[320,50],[300,50]]},{"window":[0,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50],[250,360],[240,400]]}],"bids":[{"bidder":"appnexus","params":{"placementId":12729470,"supplyType":"web","position":"above","keywords":{"fdate":["20221012"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["UKAA"],"country":["KZ"],"state":["ALA"],"cuhd":["18"],"cuhi":["61"],"cuuv":["3"],"cuwd":["4"],"cuwx":["1"],"realfeel":["70","a75","b75","c75","d75"],"fc1hi":["74"],"fc1lo":["45"],"fc1wx":["1"],"lfscategory":["heat"],"lfsday":["5"],"lfsseverity":["7"],"lfs":["7_heat_5"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/local_home"]},"reserve":0.05},"isBuyItNow":false},{"bidder":"appnexus","params":{"placementId":18044795,"supplyType":"web","position":"above","keywords":{"fdate":["20221012"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["UKAA"],"country":["KZ"],"state":["ALA"],"cuhd":["18"],"cuhi":["61"],"cuuv":["3"],"cuwd":["4"],"cuwx":["1"],"realfeel":["70","a75","b75","c75","d75"],"fc1hi":["74"],"fc1lo":["45"],"fc1wx":["1"],"lfscategory":["heat"],"lfsday":["5"],"lfsseverity":["7"],"lfs":["7_heat_5"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/local_home"]},"reserve":4.0},"isBuyItNow":true},{"bidder":"ix","params":{"siteId":197757,"size":[728,90],"bidFloor":0.05,"bidFloorCur":"USD"},"isBuyItNow":false},{"bidder":"ix","params":{"siteId":197759,"size":[970,250],"bidFloor":0.05,"bidFloorCur":"USD"},"isBuyItNow":false},{"bidder":"ix","params":{"siteId":495861,"size":[970,250],"bidFloor":4.0,"bidFloorCur":"USD"},"isBuyItNow":true},{"bidder":"rubicon","params":{"siteId":135890,"zoneId":640474,"sizes":[2,55,57],"position":"atf","accountId":"12562","floor":0.1},"isBuyItNow":false},{"bidder":"rubicon","params":{"siteId":135890,"zoneId":1518598,"sizes":[2,55,57],"position":"atf","accountId":"12562","floor":4.5},"isBuyItNow":true},{"bidder":"triplelift","params":{"inventoryCode":"accuweather_d_top_leaderboard_pbjs","floor":0.05},"isBuyItNow":false},{"bidder":"criteo","params":{"publisherSubId":"Web Top","networkId":3852},"isBuyItNow":false},{"bidder":"pubmatic","params":{"adSlot":"/706795/Web_HB_Top","publisherId":"34576","kadfloor":"0.05"},"isBuyItNow":false},{"bidder":"yahoossp","params":{"pos":"web_hb_top_1","dcn":"8a9691d3017474551cc955a9acbd0027"},"isBuyItNow":false},{"bidder":"grid","params":{"uid":"6028"},"isBuyItNow":false},{"bidder":"openx","params":{"unit":"539580665","delDomain":"accuweather-d.openx.net","customParams":{"fdate":["20221012"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["UKAA"],"country":["KZ"],"state":["ALA"],"cuhd":["18"],"cuhi":["61"],"cuuv":["3"],"cuwd":["4"],"cuwx":["1"],"realfeel":["70","a75","b75","c75","d75"],"fc1hi":["74"],"fc1lo":["45"],"fc1wx":["1"],"lfscategory":["heat"],"lfsday":["5"],"lfsseverity":["7"],"lfs":["7_heat_5"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/local_home"]},"customFloor":0.02},"isBuyItNow":false}]},"adType":"top","viewport":"tablet desktop","adDivId":"top","adUnitCode":"/6581/web/asi/top/weather/local_home","upr":0.7,"includeInSRA":true},"native":{"config":{"sizes":["fluid",[2,2]],"bids":[{"bidder":"appnexus","params":{"placementId":16139770,"supplyType":"web","keywords":{"fdate":["20221012"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["UKAA"],"country":["KZ"],"state":["ALA"],"cuhd":["18"],"cuhi":["61"],"cuuv":["3"],"cuwd":["4"],"cuwx":["1"],"realfeel":["70","a75","b75","c75","d75"],"fc1hi":["74"],"fc1lo":["45"],"fc1wx":["1"],"lfscategory":["heat"],"lfsday":["5"],"lfsseverity":["7"],"lfs":["7_heat_5"],"pt":["0"],"adunit":["/6581/web/asi/native/weather/local_home"]},"reserve":0.05},"isBuyItNow":false},{"bidder":"triplelift","params":{"inventoryCode" ...
# 		var fcConsentCookie = '';
# 		function gptLazyLoading() {
# 			if (window?.globalAdConfig?.lazyLoadingData) {
# 				try {
# 					const data = JSON.parse(window.globalAdConfig.lazyLoadingData.replace(/(['"])?([a-z0-9A-Z_]+)(['"])?:/g, '"$2": '));
# 					if (typeof data === 'object' && Object.keys(data).length > 0) {
# 						return data;
# 					}
# 				} catch (error) {
# 				}
# 			}
# 			return null;
# 		}
#     </script>
#     <script>
#      var gaAppConfig = {
#   "snowfallMap": true,
#   "mapCta": true,
#   "iceChart": true,
#   "winterOutlookCard": true,
#   "winterUpcomingCard": true,
#   "impactedCities": true,
#   "tempWindChart": true,
#   "snowfallChart": true,
#   "postEventCta": true,
#   "winterCenterMap": true
# };
# 	var userCookie = {"cDate":"2022-10-12","isDarkMapStyle":false,"lang":"en-us","rl":["222191"],"tp":"C","userContentAffinity":{}};
# 	var recentLocations = [{"adminArea":{"englishName":"Almaty","id":"ALA","localizedName":"Almaty"},"alertCount":0,"country":{"englishName":"Kazakhstan","id":"KZ","localizedName":"Kazakhstan"},"icon":1,"key":"222191","localizedName":"Almaty","postalCode":"","temp":"16°","realFeel":"20°"}];
# 	var currentLocation = {"plumeLabsLink":"https://air.plumelabs.com/air-quality-in-almaty-6p56","englishName":"Almaty","gmtOffset":6.0,"hasAlerts":false,"hasForecastConfidence":true,"hasPollen":false,"hasMinuteCast":true,"hasFutureRadar":true,"lat":43.255,"lon":76.913,"region":{"englishName":"Asia","id":"ASI","localizedName":"Asia"},"timeZone":"ALMT","timeZoneCode":"ALMT","administrativeArea":{"englishName":"Almaty","id":"ALA","localizedName":"Almaty"},"country":{"englishName":"Kazakhstan","id":"KZ","localizedName":"Kazakhstan"},"key":"222191","localizedName":"Almaty","primaryPostalCode":""};
# 	var serverAdsOnPage = [{"config":{"responsiveSizes":[{"window":[1024,0],"sizes":["fluid",[980,120],[980,90],[970,250],[970,90],[950,90],[930,180],[750,100],[750,300],[750,200],[728,90]]},{"window":[768,0],"sizes":["fluid",[728,90],[468,60],[320,50],[300,50]]},{"window":[0,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50],[250,360],[240,400]]}],"bids":[{"bidder":"appnexus","params":{"placementId":12729470,"supplyType":"web","position":"above","keywords":{"fdate":["20221012"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["UKAA"],"country":["KZ"],"state":["ALA"],"cuhd":["18"],"cuhi":["61"],"cuuv":["3"],"cuwd":["4"],"cuwx":["1"],"realfeel":["70","a75","b75","c75","d75"],"fc1hi":["74"],"fc1lo":["45"],"fc1wx":["1"],"lfscategory":["heat"],"lfsday":["5"],"lfsseverity":["7"],"lfs":["7_heat_5"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/local_home"]},"reserve":0.05},"isBuyItNow":false},{"bidder":"appnexus","params":{"placementId":18044795,"supplyType":"web","position":"above","keywords":{"fdate":["20221012"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["UKAA"],"country":["KZ"],"state":["ALA"],"cuhd":["18"],"cuhi":["61"],"cuuv":["3"],"cuwd":["4"],"cuwx":["1"],"realfeel":["70","a75","b75","c75","d75"],"fc1hi":["74"],"fc1lo":["45"],"fc1wx":["1"],"lfscategory":["heat"],"lfsday":["5"],"lfsseverity":["7"],"lfs":["7_heat_5"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/local_home"]},"reserve":4.0},"isBuyItNow":true},{"bidder":"ix","params":{"siteId":197757,"size":[728,90],"bidFloor":0.05,"bidFloorCur":"USD"},"isBuyItNow":false},{"bidder":"ix","params":{"siteId":197759,"size":[970,250],"bidFloor":0.05,"bidFloorCur":"USD"},"isBuyItNow":false},{"bidder":"ix","params":{"siteId":495861,"size":[970,250],"bidFloor":4.0,"bidFloorCur":"USD"},"isBuyItNow":true},{"bidder":"rubicon","params":{"siteId":135890,"zoneId":640474,"sizes":[2,55,57],"position":"atf","accountId":"12562","floor":0.1},"isBuyItNow":false},{"bidder":"rubicon","params":{"siteId":135890,"zoneId":1518598,"sizes":[2,55,57],"position":"atf","accountId":"12562","floor":4.5},"isBuyItNow":true},{"bidder":"triplelift","params":{"inventoryCode":"accuweather_d_top_leaderboard_pbjs","floor":0.05},"isBuyItNow":false},{"bidder":"criteo","params":{"publisherSubId":"Web Top","networkId":3852},"isBuyItNow":false},{"bidder":"pubmatic","params":{"adSlot":"/706795/Web_HB_Top","publisherId":"34576","kadfloor":"0.05"},"isBuyItNow":false},{"bidder":"yahoossp","params":{"pos":"web_hb_top_1","dcn":"8a9691d3017474551cc955a9acbd0027"},"isBuyItNow":false},{"bidder":"grid","params":{"uid":"6028"},"isBuyItNow":false},{"bidder":"openx","params":{"unit":"539580665","delDomain":"accuweather-d.openx.net","customParams":{"fdate":["20221012"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["UKAA"],"country":["KZ"],"state":["ALA"],"cuhd":["18"],"cuhi":["61"],"cuuv":["3"],"cuwd":["4"],"cuwx":["1"],"realfeel":["70","a75","b75","c75","d75"],"fc1hi":["74"],"fc1lo":["45"],"fc1wx":["1"],"lfscategory":["heat"],"lfsday":["5"],"lfsseverity":["7"],"lfs":["7_heat_5"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/local_home"]},"customFloor":0.02},"isBuyItNow":false}]},"adType":"top","viewport":"tablet desktop","adDivId":"top","adUnitCode":"/6581/web/asi/top/weather/local_home","upr":0.7,"includeInSRA":true},{"config":{"sizes":["fluid",[2,2]],"bids":[{"bidder":"appnexus","params":{"placementId":16139770,"supplyType":"web","keywords":{"fdate":["20221012"],"advelvet":["18"],"pgview":["1"],"partner":["accuweather"],"ufdb":["UKAA"],"country":["KZ"],"state":["ALA"],"cuhd":["18"],"cuhi":["61"],"cuuv":["3"],"cuwd":["4"],"cuwx":["1"],"realfeel":["70","a75","b75","c75","d75"],"fc1hi":["74"],"fc1lo":["45"],"fc1wx":["1"],"lfscategory":["heat"],"lfsday":["5"],"lfsseverity":["7"],"lfs":["7_heat_5"],"pt":["0"],"adunit":["/6581/web/asi/native/weather/local_home"]},"reserve":0.05},"isBuyItNow":false},{"bidder":"triplelift","params":{"inventoryCode":"accuweather_d_weat ...
# 	var weatherEvents = [];
# 	var userData = {"city":"ALMATY","continent":1,"countryCode":"KZ","county":"","lat":43.25,"lon":76.95,"regionCode":"","throughput":"vhigh","bw":"5000","networkType":"","device":{}};
# 	var showPrivacyPolicyBanner = true;
# 	var consentCookie = '.AspNet.Consent=yes; expires=Thu, 12 Oct 2023 05:38:10 GMT; path=/; samesite=lax';
# 	var mapbox={token:'pk.eyJ1IjoiYWNjdXdlYXRoZXItaW5jIiwiYSI6ImNqeGtxeDc4ZDAyY2czcnA0Ym9ubzh0MTAifQ.HjSuXwG2bI05yFYmc0c9lw',style:'mapbox://styles/accuweather-inc/cjknc24na2o5u2sqoy0t8ku8a'};
# 	var dts={token:'de13920f574d420984d3080b1fa6132b'};
# 	setTimeout(function() {
# 		var reg = new RegExp('(\\s|^)' + 'ads-not-loaded' + '(\\s|$)');
# 		if (document.body.hasAttribute('class')) {
# 			document.body.setAttribute('class', document.body.getAttribute('class').replace(reg, ' '));
# 		}
# 	}, 3000);
#     </script>
#     <script>
#      var hostEnvironment = 'Production-NEURO-K8S';
# 	var pageId = 'three-day';
# 	var siteVersion = "2.2.19.0";
# 	var activeFeatureTest = '';
#     </script>
#     <script>
#      const startMetric=Date.now();function measureTiming(t){var e=Date.now()-startMetric;console.log(t+": "+e);window[t]=e}
#     </script>
#     <script>
#      window.isUserCountryEEA = false;
#     </script>
#     <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/prebid-a.c5b035e6b410954149cf.js">
#     </script>
#     <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#     </script>
#     <script>
#      window.pbjs = window.pbjs || {};
# 		pbjs.que = pbjs.que || [];
# 		// Initialize ad info
# 		window.measureTiming('AdManager_Initialization');
# 		adInfo['hour'] = new Date().getHours().toString();
# 		const width = document.documentElement.clientWidth;
# 		const height = document.documentElement.clientHeight;
# 		const round = x => Math.ceil(x / 10) * 10;
# 		adInfo['viewport'] = `${round(width)}x${round(height)}`;
# 		adInfo['site'] = width >= 768
# 			? (width >= 1024 ? 'desktop' : 'tablet')
# 			: 'mobile';
# 		// Helper function for uprTargeting
# 		window.uprTargeting = (gptSlot, adObject) => {
#
# 				const highestPrebid = pbjs?.getHighestCpmBids ? pbjs.getHighestCpmBids(adObject.adUnitCode) : [];
# 				const prebidCPM = highestPrebid.length ? highestPrebid[0].cpm || 0 : 0;
# 				const round = (n) => {
# 					if (n > 15) {
# 						return '15.00';
# 					} else if (n > 10) {
# 						return String(Math.round(n).toFixed(2));
# 					} else {
# 						// Round to closest half
# 						return String((Math.round(n * 2) / 2).toFixed(2));
# 					}
# 				};
# 				const upr_0 = prebidCPM ? round(prebidCPM) : 'no_bid';
# 				let hb_bid_1st = 'no_bid';
# 				let hb_bid_2nd = 'no_bid';
# 				if (pbjs?.getBidResponsesForAdUnitCode) {
# 					const formatCpm = (cpm) => (Math.round(cpm * 10) / 10).toFixed(2);
# 					const bidResponses = pbjs.getBidResponsesForAdUnitCode(adObject.adUnitCode).bids;
# 					bidResponses.sort((a, b) => b.cpm - a.cpm);
# 					if (bidResponses[0]) {
# 						hb_bid_1st = formatCpm(bidResponses[0].cpm);
# 					}
# 					if (bidResponses[1]) {
# 						hb_bid_2nd = formatCpm(bidResponses[1].cpm);
# 					}
# 				}
# 				const uprTargeting = {
# 					upr: adObject.upr,
# 					upr_0,
# 					upr_auction: 'prebid',
# 					userid3pbid: `${window.adInfo['userid3p']}-${upr_0}`,
# 					hb_bid_1st,
# 					hb_bid_2nd,
# 				};
# 							if (gptSlot) {
# 				Object.keys(uprTargeting).forEach((key) => {
# 					if (uprTargeting[key]) {
# 						gptSlot.setTargeting(key, String(uprTargeting[key]));
# 					}
# 				});
# 			}
# 			return uprTargeting;
# 		};
#     </script>
#     <script>
#      const BIDDING_TIMEOUT = (window.globalAdConfig && typeof window.globalAdConfig.prebidTimeout === 'number') ? window.globalAdConfig.prebidTimeout : 750;
# 		// Initialize prebid
# 		pbjs.que.push(() => {
# 			// Pbjs config
# 			const weatherLocData = window.currentLocation;
# 			let ortb2Geo = {};
# 			if (weatherLocData?.country?.id === 'US') {
# 				ortb2Geo = {
# 					country: 'usa',
# 					region: weatherLocData.administrativeArea?.id,
# 					metro: weatherLocData.dma?.id,
# 					city: weatherLocData.englishName,
# 					zip: weatherLocData.primaryPostalCode,
# 					utcoffset: weatherLocData.gmtOffset * 60,
# 				};
# 			}
# 			const ortb2User = { data: {} };
# 			(['userid', 'userid3p', 'partner', 'pgview', 'pt', 'viewport', 'hour']).forEach((key) => {
# 				if (window.adInfo && window.adInfo[key]) {
# 					ortb2User.data[key] = window.adInfo[key].replaceAll('-', 'neg');
# 				}
# 			});
# 			const ortbSiteConfig = window.globalAdConfig?.ortbSite;
# 			let ortb2Site = {
# 				name: 'AccuWeather',
# 				domain: 'www.accuweather.com',
# 				cat: ['IAB-7', 'IAB7-4', 'IAB15-10', 'IAB20', '288', '390', '653'],
# 				page: `${window.location.protocol}//${window.location.host}${window.location.pathname}`,
# 				ref: document.referrer,
# 				mobile: 1,
# 				privacypolicy: 1,
# 				publisher: {
# 					name: 'AccuWeather',
# 					domain: 'www.accuweather.com',
# 					cat: ['IAB-7', 'IAB7-4', 'IAB15-10', 'IAB20', '288', '390', '653'],
# 				},
# 				content: {
# 					language: window.userCookie?.lang?.substring(0, 2),
# 				},
# 				ext: {
# 					data: {},
# 				},
# 			};
# 			if (ortbSiteConfig) {
# 				ortb2Site = {
# 					name: ortbSiteConfig.name,
# 					domain: ortbSiteConfig.domain,
# 					cat: ortbSiteConfig.categories,
# 					page: `${window.location.protocol}//${window.location.host}${window.location.pathname}`,
# 					ref: document.referrer,
# 					mobile: ortbSiteConfig.mobile,
# 					privacypolicy: ortbSiteConfig.privacyPolicy,
# 					publisher: {
# 						name: ortbSiteConfig.publisher.name,
# 						domain: ortbSiteConfig.publisher.domain,
# 						cat: ortbSiteConfig.publisher.categories,
# 					},
# 					content: {
# 						language: window.userCookie?.lang?.substring(0, 2),
# 						title: document.title,
# 						keywords: ortbSiteConfig.content.keywords,
# 						url: `${window.location.protocol}//${window.location.host}${window.location.pathname}`,
# 						cat: ortbSiteConfig.content.categories,
# 						prodq: parseInt(ortbSiteConfig.content.productQuality),
# 						context: parseInt(ortbSiteConfig.content.context),
# 						sourcerelationship: ortbSiteConfig.content.sourceRelationship,
# 						data: [{
# 							name: ortbSiteConfig.content.data.name,
# 							ext: ortbSiteConfig.content.data.extensions,
# 							segment: ortbSiteConfig.content.data.segments
# 						}]
# 					},
# 					sectioncat: ortbSiteConfig.sectionCategories,
# 					pagecat: ortbSiteConfig.pageCategories,
# 					keywords: ortbSiteConfig.keywords,
# 					ext: {
# 						data: {},
# 					},
# 				};
# 			}
# 			(['advelvet', 'country', 'cuhd', 'cuhi', 'cuuv', 'cuwd', 'cuwx',
# 			'dma', 'fdate', 'state', 'wx_seg', 'ufdb', 'alertscategory', 'alertssource',
# 			'alertstypeid', 'site', 'realfeel']).forEach((key) => {
# 				if (window.adInfo && window.adInfo[key]) {
# 					ortb2Site.ext.data[key] = window.adInfo[key].replaceAll('-', 'neg').split(',');
# 				}
# 			});
# 			// Add ortb2.site.ext.data.bin_top and ortb2.site.ext.data.upr_top
# 			if (window.serverAdsOnPageLite?.top) {
# 				const { upr, config } = window.serverAdsOnPageLite.top;
# 				const binTop = config.bids.find(bid => (bid.bidder === 'rubicon' && bid.isBuyItNow));
# 				ortb2Site.ext.data.bin_top = binTop?.params?.floor;
# 				ortb2Site.ext.data.upr_top = upr;
# 			}
# 			const config = {
# 				bidderTimeout: BIDDING_TIMEOUT,
# 				enableSendAllBids: false,
# 				disableAjaxTimeout: true,
# 				maxRequestsPerOrigin: 6,
# 				priceGranularity: {
# 					buckets: [
# 						{
# 							precision: 2,
# 							max: 3,
# 							increment: 0.01,
# 						},
# 						{
# 							precision: 2,
# 							max: 8,
# 							increment: 0.05,
# 						},
# 						{
# 							precision: 2,
# 							max: 20,
# 							increment: 0.5,
# 						},
# 						{
# 							precision: 2,
# 							max: 100,
# 							increment: 1,
# 						},
# 					],
# 				},
# 				userSync: {
# 					filterSettings: {
# 						iframe: {
# 							bidders: '*',
# 							filter: 'include',
# 						},
# 					},
# 					syncsPerBidder: 0,
# 					aliasSyncEnabled: true,
# 					syncDelay: 6000,
# 					userIds: [
# 						{
# 							name: 'pubCommonId',
# 							storage: {
# 								type: 'cookie',
# 								name: '_pubcid', // create a cookie with this name
# 								expires: 365, // expires in 1 years
# 							},
# 						},
# 						{
# 							name: 'merkleId',
# 							params: {
# 								vendor: 'idsv2',
# 								sv_cid: '5344_04531',
# 								sv_pubid: '12562',
# 								sv_domain: 'accuweather.com',
# 								endpoint: 'https://id2.sv.rkdms.com/identity/'
# 							},
# 							storage: {
# 								type: 'html5',
# 								name: 'merkleId',
# 								expires: 30,
# 							},
# 						},
# 					],
# 				},
# 				cache: {
# 					url: 'https://prebid.adnxs.com/pbc/v1/cache',
# 				},
# 				consentManagement: {
# 					usp: {
# 						cmpApi: 'static',
# 						consentData: {
# 							getUSPData: {
# 								uspString: '',
# 							},
# 						},
# 					},
# 				},
# 				rubicon: {
# 					singleRequest: true,
# 				},
# 				yahoossp: {
# 					endpoint: 'https://webc2s.pubgw.yahoo.com/pubgw/v1/hb/web/prebid',
# 					singleRequestMode: true
# 				},
# 				useBidCache: true,
# 				bidCacheFilterFunction: bid => bid.mediaType !== 'video',
# 				timeoutBuffer: 0,
# 				ortb2: {
# 					site: ortb2Site,
# 					user: {
# 						ext: ortb2User,
# 						geo: ortb2Geo,
# 					},
# 				},
# 			};
# 			if (window.isUserCountryEEA) {
# 				config.consentManagement = {
# 					gdpr: {
# 						cmpApi: 'iab',
# 						defaultGdprScope: true,
# 						timeout: 0,
# 					},
# 				};
# 			}
# 			pbjs.setConfig(config);
# 			pbjs.bidderSettings = {
# 				pubmatic: {
# 					bidCpmAdjustment(bidCpm) {
# 						return bidCpm * (1 - 0.15);
# 					},
# 				},
# 			};
# 			// Create and push pbjs ad units
# 			const ALLOWED_SIZES = {
# 				top: ['300x250', '320x50', '300x50', '336x280', '728x90', '970x250', '970x90'],
# 				top_right: ['300x250', '300x600', '160x600'],
# 				bottom_right: ['300x250', '300x600', '160x600'],
# 				bottom: ['300x250', '320x50', '300x50', '300x600', '336x280', '728x90', '970x250', '970x90'],
# 				adhesion: ['320x50', '300x50'],
# 				middle: ['300x250', '320x50', '300x50', '300x600', '336x280'],
# 				native: ['1x1', '2x2'],
# 				infeed: ['1x1', '2x2'],
# 			};
# 			(Object.keys(window.serverAdsOnPageLite) || []).forEach((key) => {
# 				const { adUnitCode, adType, config = {} } = window.serverAdsOnPageLite[key];
# 				let { responsiveSizes = [], bids = [], sizes = [] } = config;
# 				// Only add pbjs ad unit if we have bids for the ad slot
# 				if (bids.length) {
# 					// If responsiveSizes are defined, use it for sizes
# 					responsiveSizes.forEach(respSize => {
# 						if (sizes.length === 0 && document.documentElement.clientWidth >= respSize.window[0]) {
# 							sizes = respSize.sizes;
# 						}
# 					});
# 					const filteredSizes = sizes.filter((size) => {
# 						const allowedSizes = ALLOWED_SIZES[adType] || [];
# 						return Array.isArray(size) && allowedSizes.indexOf(size.join('x')) > -1;
# 					});
# 					const userData = window.userData;
# 					if (userData?.countryCode?.toLowerCase() !== 'us') {
# 						bids = bids.filter((bid) => bid.bidder !== 'yahoossp');
# 					}
# 					// Remove BuyItNow bids from mWeb top slot on current and hourly pages
# 					const pageTemplate = window.adPageInfo ? window.adPageInfo.template : '';
# 					if (adUnitCode.indexOf('mweb') >= 0 && adType === 'top' && ['current', 'hourly'].indexOf(pageTemplate) > -1) {
# 						// Update for RW-3718: only suppress BuyItNow from IX
# 						bids = bids.filter((bid) => bid.bidder !== 'ix' || !bid.isBuyItNow);
# 					}
# 					const mediaTypes = {
# 						banner: {
# 							sizes: filteredSizes,
# 						},
# 					};
# 					if (adType === 'native' || adType === 'infeed') {
# 						mediaTypes.native = {
# 							type: 'image',
# 						};
# 					}
# 					pbjs.addAdUnits({
# 						bids,
# 						mediaTypes,
# 						code: adUnitCode,
# 						ortb2Imp: { ext: { data: { pbadslot: adUnitCode }, gpid: adUnitCode }},
# 					});
# 				}
# 			});
# 		});
# 		// Prebid fetch promise
# 		const fetchPrebidBids = (adUnitCodes = []) => {
# 			let IS_BID_REQUESTED = false;
# 			return new Promise((resolve) => {
# 				const requestBids = () => {
# 					if (IS_BID_REQUESTED) {
# 						return resolve();
# 					}
# 					IS_BID_REQUESTED = true;
# 					window.measureTiming('AdManager_RequestAllBids');
# 					try {
# 						pbjs.requestBids({
# 							adUnitCodes,
# 							timeout: BIDDING_TIMEOUT,
# 							bidsBackHandler: (prebidBids) => {
# 								resolve(prebidBids);
# 							},
# 						});
# 					} catch (error) {
# 						console.warn('Ad manager: error pbjs.requestBids', error);
# 						resolve();
# 					}
# 				};
# 				pbjs.que.push(() => {
# 					// If user is in EEA, we will need to wait for consent before requesting bids
# 					if (window.isUserCountryEEA) {
# 						// If we already have cached consent, go ahead and request bids
# 						if (window.fcConsentCookie === '1') {
# 							// Setup tcfapi stub and return cached data
# 							window.__tcfapi = (command, version, callback) => {
# 								const tcData = JSON.parse(localStorage.getItem('awxTcData') || '{}');
# 								if (tcData.tcString) {
# 									switch (command) {
# 										case 'addEventListener':
# 										case 'getTCData':
# 											if (typeof callback === 'function') {
# 												callback(tcData, true);
# 											}
# 											break;
# 									}
# 								} else {
# 									// delete consent cookie if something is wrong with tcData
# 									document.cookie = 'awxconsent=; Max-Age=0; path=/';
# 								}
# 							};
# 							requestBids();
# 						}
# 						// Else, we wait for consent response first
# 						else if (window.googlefc) {
# 							// When we have consent data, cache the response and then request the bids
# 							const onConsentReady = () => {
# 								if (window.__tcfapi) {
# 									window.__tcfapi('addEventListener', 2, (tcData, success) => {
# 										const shouldSaveTCData = tcData && tcData.tcString && (tcData.gdprApplies === false || tcData.eventStatus === 'tcloaded' || tcData.eventStatus === 'useractioncomplete');
# 										if (success && shouldSaveTCData) {
# 											localStorage.setItem('awxTcData', JSON.stringify(tcData));
# 											// Set first party cookie for 30 days
# 											const date = new Date();
# 											date.setTime(date.getTime() + (30 * 24 * 60 * 60 * 1000));
# 											document.cookie = 'awxconsent=1; expires=' + date.toUTCString() + '; path=/';
# 										}
# 									});
# 								}
# 								requestBids();
# 							};
# 							window.googlefc.callbackQueue = window.googlefc.callbackQueue || [];
# 							window.googlefc.callbackQueue.push({
# 								CONSENT_DATA_READY: onConsentReady,
# 							});
# 							setTimeout(requestBids, 9000);
# 						}
# 					} else {
# 						requestBids();
# 					}
# 				});
# 			});
# 		};
# 		window.renderPrebidWithIframe = (adObject, bid) => {
# 			const adDivEl = document.getElementById(adObject.adDivId);
# 			adDivEl.innerHTML = '';
# 			const isNotForSafeFrame = bid.width <= 2 || bid.height <= 2;
#
# 			const iframe = document.createElement('iframe');
#
# 			if (!isNotForSafeFrame) {
# 				iframe.setAttribute(
# 					'src',
# 					'https://www.awxcdn.com/safeframe/1-0-0/html/container.html'
# 				);
# 				iframe.setAttribute('name', bid.adId);
# 				iframe.setAttribute(
# 					'sandbox',
# 					'allow-forms allow-pointer-lock allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation'
# 				);
# 				iframe.setAttribute('height', bid.height);
# 				iframe.setAttribute('width', bid.width);
# 			}
# 			iframe.setAttribute('style', 'display:block;margin:auto');
# 			iframe.setAttribute('frameborder', 0);
# 			iframe.setAttribute('scrolling', 'no');
# 			iframe.setAttribute('marginheight', 0);
# 			iframe.setAttribute('marginwidth', 0);
# 			iframe.setAttribute('TOPMARGIN', 0);
# 			iframe.setAttribute('LEFTMARGIN', 0);
# 			iframe.setAttribute('allowtransparency', 'true');
# 			adDivEl.appendChild(iframe);
# 			if (isNotForSafeFrame) {
# 				pbjs.renderAd(iframe.contentWindow.document, bid.adId);
# 			}
# 		};
#     </script>
#     <script>
#      window.prebidTimeoutPromise = new Promise((resolve) => {
# 					pbjs.que.push(() => {
# 						pbjs.onEvent('auctionInit', () => {
# 							setTimeout(resolve, BIDDING_TIMEOUT);
# 						});
# 					});
# 				});
# 				const buyItNowBids = [];
# 				pbjs.que.push(() => {
# 					pbjs.onEvent('auctionInit', (auction) => {
# 						auction.bidderRequests.forEach((bidder) => {
# 							bidder.bids.forEach((bid) => {
# 								if (bid.isBuyItNow) {
# 									buyItNowBids.push(bid.bidId);
# 								}
# 							});
# 						});
# 					});
# 				});
# 				window.prebidBidPromise = fetchPrebidBids();
# 					// Start ad process
# 		window.googletag = window.googletag || { cmd: [] };
# 		googletag.cmd.push(function() {
# 			window.measureTiming('GPT_Initialization');
# 			googletag.pubads().disableInitialLoad();
# 			googletag.pubads().enableAsyncRendering();
# 			if (!window.globalAdConfig || window.globalAdConfig.enableSingleRequest) {
# 				googletag.pubads().enableSingleRequest();
# 			}
# 			googletag.pubads().setCentering(true);
# 			googletag.pubads().setSafeFrameConfig({
# 				allowOverlayExpansion: false,
# 				allowPushExpansion: true,
# 				sandbox: true,
# 			});
# 			// Set page level targeting
# 			for (const [key, value] of Object.entries(adInfo)) {
# 				if (value) {
# 					googletag.pubads().setTargeting(key, value);
# 				}
# 			}
# 			// Set privacy settings
# 			if (adInfo.rdp === '1') {
# 				googletag.pubads().setTargeting('optout', 'true');
# 				googletag.pubads().setPrivacySettings({
# 					restrictDataProcessing: true,
# 				});
# 			} else {
# 				googletag.pubads().setTargeting('optout', 'false');
# 			}
# 			// Set ppid targeting
# 			const ppid = '35571dedfc1f4df98e5e8005023e8595';
# 			if (ppid) {
# 				googletag.pubads().setPublisherProvidedId(ppid);
# 			}
# 			// Init ad server
# 			const FAILSAFE_TIMEOUT = (window.globalAdConfig && typeof window.globalAdConfig.awxTimeout === 'number') ? window.globalAdConfig.awxTimeout : 10000;
# 			let IS_ADSERVER_INIT = false;
# 			const initAdserver = () => {
# 				if (IS_ADSERVER_INIT) {
# 					return;
# 				}
# 				IS_ADSERVER_INIT = true;
# 				measureTiming('AdManager_InitAdServer');
# 				// Define ads in order
# 				const order = ["top","top_right","infeed","bottom_right","native","bottom","oop","interstitial"];
# 				const orderedAds = Object.keys(window.serverAdsOnPageLite)
# 					.sort((a, b) => order.indexOf(a.split('-')[0]) - order.indexOf(b.split('-')[0]))
# 					.filter((adDivId) => order.indexOf(adDivId.split('-')[0]) > -1);
# 				const gptSlots = orderedAds.map((adDivId) => {
# 					const adsOnPage = window.serverAdsOnPageLite || {};
# 					const adObject = adsOnPage[adDivId];
# 					if (adObject && document.getElementById(adObject.adDivId)) {
# 						// Check if buy it now bids won
# 						let highestBid = { cpm: 0 };
# 						if (pbjs?.getBidResponsesForAdUnitCode) {
# 							const bidResponses = pbjs.getBidResponsesForAdUnitCode(adObject.adUnitCode);
# 							// Get the BuyItNow bid with highest cpm
# 							bidResponses.bids.forEach((bid) => {
# 								if (buyItNowBids.indexOf(bid.requestId) > -1 && bid.cpm > highestBid.cpm) {
# 									highestBid = bid;
# 								}
# 							});
# 						}
# 						// If BuyItNow is valid, change the ad unit code geo part to bin_prebid
# 						//  - then if skipGoogleAdManager is true, render the creative and create an oop ad unit for DFP tracking
# 						//  - else, return the gptSlot with the new ad code
# 						// otherwise return the gptSlot with the original ad code
# 						if (highestBid.cpm > 0) {
# 							const adCode = adObject.adUnitCode.split('/');
# 							adCode[3] = 'bin_prebid';
# 							adObject.code = adCode.join('/');
# 							// Sets the pug page-level targeting
# 							googletag.pubads().setTargeting('pug', '1');
# 							if (!window.globalAdConfig || window.globalAdConfig.skipGoogleAdManager) {
# 								window.renderPrebidWithIframe(adObject, highestBid);
# 								// Create the bin_prebid tracking slot
# 								const oopId = `${adObject.adDivId}-oop`;
# 								const oopDiv = document.createElement('div');
# 								oopDiv.setAttribute('id', oopId);
# 								oopDiv.setAttribute('class', 'tracking-slot');
# 								document.body.appendChild(oopDiv);
# 								const gptSlot = googletag.defineOutOfPageSlot(adObject.code, oopId);
# 								gptSlot?.addService(googletag.pubads());
# 								Object.keys(highestBid.adserverTargeting).forEach((key) => {
# 									gptSlot.setTargeting(key, highestBid.adserverTargeting[key]);
# 								});
# 								if (window.adInfo) {
# 									if (window.adInfo.partner) {
# 										gptSlot.setTargeting('partner', window.adInfo.partner);
# 									}
# 									gptSlot.setTargeting('userid3p', window.adInfo.userid3p);
# 								}
# 								adObject.gptSlot = gptSlot;
# 								return gptSlot;
# 							}
# 						}
# 						// Get sizes from config
# 						let { sizes = [], responsiveSizes = [] } = adObject.config || {};
# 						let gptSlot;
# 						// If responsiveSizes are defined, use it for sizes
# 						responsiveSizes.forEach(respSize => {
# 							if (sizes.length === 0 && document.documentElement.clientWidth >= respSize.window[0]) {
# 								sizes = respSize.sizes;
# 							}
# 						});
# 						if (adObject.adType === 'oop') {
# 							gptSlot = googletag.defineOutOfPageSlot(adObject.adUnitCode, adObject.adDivId);
# 						} else if (adObject.adType === 'interstitial') {
# 							gptSlot = googletag.defineOutOfPageSlot(adObject.adUnitCode, googletag.enums.OutOfPageFormat.INTERSTITIAL);
# 						} else {
# 							gptSlot = googletag.defineSlot(adObject.adUnitCode, sizes, adObject.adDivId);
# 						}
# 						if (responsiveSizes && responsiveSizes.length > 0) {
# 							const mapping = googletag.sizeMapping();
# 							responsiveSizes.forEach((mapObject) => {
# 								mapping.addSize(mapObject.window, mapObject.sizes);
# 							});
# 							gptSlot.defineSizeMapping(mapping.build());
# 						}
# 						window.uprTargeting(gptSlot, adObject);
# 						gptSlot?.addService(googletag.pubads());
# 						adObject.gptSlot = gptSlot;
# 						// Only return the gptSlot that's included in initial request
# 						if (adObject.includeInSRA) {
# 							return gptSlot;
# 						}
# 					}
# 					return null;
# 				}).filter((x) => x);
# 				const lazyLoadingData = window.gptLazyLoading();
# 				if (lazyLoadingData) {
# 					googletag.pubads().enableLazyLoad(lazyLoadingData);
# 				}
# 				// Enable services when all slots are defined
# 				googletag.enableServices();
# 				// Call display after services are enabled
# 				gptSlots.forEach((gptSlot) => {
# 					const adDivId = gptSlot.getSlotElementId();
# 					window.measureTiming(`AdManager_${adDivId}_Display`);
# 					googletag.display(adDivId);
# 				});
# 				// Renders all ads on page
# 				window.pbjs?.setTargetingForGPTAsync && pbjs.setTargetingForGPTAsync();
# 				window.measureTiming('AdManager_SetTargetingForGPTAsync');
# 				googletag.pubads().refresh(gptSlots);
# 			};
# 			// A timeout incase bidding fails or takes too long
# 			setTimeout(initAdserver, FAILSAFE_TIMEOUT);
# 			window.prebidBidPromise.then(initAdserver);
# 			googletag.pubads().addEventListener('slotRenderEnded', (event) => {
# 				if (document.body.classList.contains('ads-not-loaded')) {
# 					setTimeout(() => document.body.classList.remove('ads-not-loaded'), 750);
# 				}
# 				const adSlot = window.serverAdsOnPageLite[event.slot.getSlotElementId()];
# 				if (adSlot) {
# 					const renderedAdEl = document.getElementById(adSlot.adDivId);
# 					if (renderedAdEl) {
# 						setTimeout(() => {
# 							renderedAdEl.classList.remove('unrendered');
# 						}, 250);
# 					}
# 				}
# 			});
# 			let isInterstitialRendered = false;
# 			googletag.pubads().addEventListener('slotResponseReceived', () => {
# 				if (!isInterstitialRendered && window.serverAdsOnPageLite['interstitial']) {
# 					isInterstitialRendered = true;
# 					const { gptSlot } = window.serverAdsOnPageLite['interstitial'];
# 					if (gptSlot) {
# 						googletag.display(gptSlot.getSlotElementId());
# 						googletag.pubads().refresh([gptSlot]);
# 					}
# 				}
# 			});
# 		});
#     </script>
#     <script>
#      function getAwxSession(categories, pageId) {
# 	const AWX_SESSION_NAME = 'awx_session';
# 	const defaultVal = {
# 		categoryFlow: [],
# 		visitFlow: [],
# 		ttl: Date.now() + 600000
# 	};
#
# 	let awxSession = JSON.parse(window.localStorage.getItem(AWX_SESSION_NAME) || '{}');
# 	if (!awxSession.ttl || Date.now() > awxSession.ttl) {
# 		awxSession = defaultVal;
# 	}
#
# 	if (categories) {
# 		categories = categories.toLowerCase().replace(/\s/g, '-');
# 		awxSession.categoryFlow = awxSession.categoryFlow.concat(categories.split('|')).slice(-30);
# 	}
#
# 	if (pageId) {
# 		awxSession.visitFlow.push(pageId);
# 	}
#
# 	try {
# 		window.localStorage.setItem(AWX_SESSION_NAME, JSON.stringify(awxSession));
# 	} catch {};
#
# 	return {
# 		categoryFlow: awxSession.categoryFlow.join('/'),
# 		visitFlow: awxSession.visitFlow.join('/'),
# 		visitFlowArray: awxSession.visitFlow
# 	};
# }
#
# function getUserContentAffinity(categories) {
# 	const storageKey = 'awxContentAffinity';
# 	const storageValue = window.localStorage.getItem(storageKey);
# 	const contentAffinity = (storageValue && storageValue !== '{}') ? JSON.parse(storageValue) : window.userCookie.userContentAffinity;
#
# 	if (categories) {
# 		categories = categories.toLowerCase().replace(/\s/g, '-');
# 		categories.split('|').forEach(function(category) {
# 			contentAffinity[category] = (contentAffinity[category] || 0) + 1;
# 		});
# 	}
#
# 	try {
# 		window.localStorage.setItem(storageKey, JSON.stringify(contentAffinity));
# 	} catch {};
#
# 	return Object.keys(contentAffinity).map(function(category) {
# 		return category + ':' + contentAffinity[category];
# 	}).join('/');
# }
#     </script>
#     <script>
#      function getCampaignLongevity() {
# 		var inBrowser = typeof window !== 'undefined';
# 		var hasLocalStorage =
# 			inBrowser &&
# 			'localStorage' in window &&
# 			window.localStorage !== null &&
# 			typeof window.localStorage.setItem === 'function' &&
# 			typeof window.localStorage.getItem === 'function';
#
# 		function getParamByName(name, url) {
# 			if (!url) url = window.location.href;
# 			name = name.replace(/[\[\]]/g, '\\$&');
# 			var regex = new RegExp('[?&]' + name + '(=([^&#]*)|&|#|$)');
# 			var results = regex.exec(url);
# 			if (!results) return null;
# 			if (!results[2]) return '';
# 			return decodeURIComponent(results[2].replace(/\+/g, ' '));
# 		}
#
# 		function getItem(name) {
# 			var value;
#
# 			if (hasLocalStorage) {
# 				try {
# 					value = window.localStorage.getItem(name);
# 				} catch (err) {
# 					console.error('Failed to read from local storage.', err);
# 				}
# 			} else {
# 				value = getCookie(name);
# 			}
#
# 			return value;
# 		};
#
# 		function setItem(name, value) {
# 			var valueAsString =
# 				typeof value === 'string' ? value : JSON.stringify(value);
# 			if (hasLocalStorage) {
# 				try {
# 					window.localStorage.setItem(name, valueAsString);
# 					return true;
# 				} catch (err) {
# 					console.error('Failed to write to local storage.', err);
# 				}
# 			} else {
# 				// Cookie fallback
# 				setCookie(name, valueAsString, 365);
# 			}
# 		};
#
# 		function setCookie(name, value, days) {
# 			var expires = "";
# 			if (days) {
# 				var date = new Date();
# 				date.setTime(date.getTime() + (days * 24 * 60 * 60 * 1000));
# 				expires = "; expires=" + date.toUTCString();
# 			}
# 			document.cookie = name + "=" + (value || "") + expires + "; path=/";
# 		}
#
# 		function getCookie(name) {
# 			var nameEQ = name + "=";
# 			var ca = document.cookie.split(';');
# 			for (var i = 0; i < ca.length; i++) {
# 				var c = ca[i];
# 				while (c.charAt(0) == ' ') c = c.substring(1, c.length);
# 				if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length, c.length);
# 			}
# 			return null;
# 		}
#
# 		var longevityCheckKey = 'utmCampaignCookie';
# 		var localUtmCampaign = getParamByName('utm_campaign');
# 		var longevityCheck = null;
# 		if (!localUtmCampaign) {
# 			return null;
# 		} else {
# 			var today = new Date();
# 			var todayEpoch = today.getTime();
#
# 			var campaignArray =
# 				JSON.parse(getItem(longevityCheckKey)) || [];
# 			var localCampaign = campaignArray.filter(function (x) {
# 				return x.campaign === localUtmCampaign
# 			})[0];
# 			if (localCampaign) {
# 				var diff = todayEpoch - parseInt(localCampaign.dateAdded || 0);
# 				var diffDays = diff / (1000 * 3600 * 24);
# 				if (diffDays < 1) {
# 					diffDays = 0;
# 				}
# 				longevityCheck = diffDays;
# 			} else {
# 				campaignArray.push({
# 					campaign: localUtmCampaign,
# 					dateAdded: todayEpoch,
# 				});
# 				setItem(longevityCheckKey, campaignArray.slice(0, 20));
# 				longevityCheck = 0;
# 			}
# 			return Math.round(longevityCheck);
# 		}
# 	}
#     </script>
#     <script>
#      window.englishTitle = "Almaty, Almaty, Kazakhstan Today, Tonight &amp; Tomorrow&#x27;s Weather Forecast | AccuWeather";
#     </script>
#     <!-- Global site tag (gtag.js) - Google Analytics -->
#     <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-CLHWQNSJ6W">
#     </script>
#     <script>
#      window.dataLayer = window.dataLayer || [];
#
# 	let pageTemplate = window.adPageInfo ? window.adPageInfo.template : '';
# 	let pageCategory = window.adPageInfo ? window.adPageInfo.category : '';
# 	let pageTitle = window.englishTitle ?? '';
# 	function gtag() { dataLayer.push(arguments); }
# 	gtag('js', new Date());
# 	gtag('config', 'G-CLHWQNSJ6W', {
# 		'page_title': pageTitle,
# 		'page_type': 'three-day',
# 		'page_url': removeURLParameter(window.location.href),
# 		'dfp_page_type': pageTemplate,
# 		'dfp_page_cat': pageCategory,
# 		'site_type': 'responsive',
# 		'partner_code': 'accuweather',
# 		'page_contains_map': '1',
# 		'send_page_view': false
# 	});
# 	const gclidPromise = new Promise(resolve => {
# 		gtag('get', 'G-CLHWQNSJ6W', 'client_id', resolve);
# 	});
# 	gclidPromise.then((client_id) => {
# 		gtag('set', 'user_properties', {
# 			'client_id': client_id,
# 			'cookie_creation_date': '2022-10-12',
# 			'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
# 			'user_content_affinity': getUserContentAffinity(''),
# 			'campaign_longevity': getCampaignLongevity()
# 		});
# 	})
#
# 	var session = getAwxSession('', `three-day`);
# 	if (session && session.visitFlowArray && Array.isArray(session.visitFlowArray) && session.visitFlowArray.length === 1) {
# 		var partner = 'accuweather'.trim();
# 		if (partner && partner !== 'accuweather') {
# 			gtag('event', 'partner_session_start', {
# 				'partner_code': 'accuweather',
# 				'timezone_offset': '6',
# 			});
# 		}
# 	}
#
# 	if (['news', 'content-landing'].indexOf('three-day') < 0) {
# 		gtag('event', 'page_view', {
# 			'page_title': pageTitle,
# 			'page_location': window.location.href,
# 			'page_path': window.location.pathname,
# 			'send_to': 'G-CLHWQNSJ6W',
# 			'author_name': '',
# 			'author_id': '',
# 			'publish_date': '',
# 			'content_id': '',
# 			'content_template': '',
# 			'content_location': '',
# 			'content_category_names': '',
# 			'content_tags': '',
# ...
#          Company
#         </div>
#         <div class="footer-category-section">
#          <a class="footer-category-section-link" data-gacategory="Company" data-gatext="Proven Superior Accuracy" href="https://corporate.accuweather.com/" target="_blank">
#           Proven Superior Accuracy
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Company" data-gatext="About AccuWeather" href="https://corporate.accuweather.com/company/about-us/" target="_blank">
#           About AccuWeather
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Company" data-gatext="Digital Advertising" href="https://advertising.accuweather.com/for-advertising/digital-advertising/" target="_blank">
#           Digital Advertising
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Company" data-gatext="Careers" href="https://corporate.accuweather.com/company/careers/" target="_blank">
#           Careers
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Company" data-gatext="Press" href="https://corporate.accuweather.com/newsroom/press-releases/" target="_blank">
#           Press
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Company" data-gatext="Contact Us" href="https://corporate.accuweather.com/company/contact/" target="_blank">
#           Contact Us
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="footer-content-category">
#        <div class="footer-content-category-wrapper">
#         <div class="footer-content-category-header">
#          Products &amp; Services
#         </div>
#         <div class="footer-category-section">
#          <a class="footer-category-section-link" data-gacategory="Products &amp; Services" data-gatext="For Business" href="https://business.accuweather.com/" target="_blank">
#           For Business
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Products &amp; Services" data-gatext="For Partners" href="https://partners.accuweather.com/" target="_blank">
#           For Partners
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Products &amp; Services" data-gatext="For Advertising" href="https://advertising.accuweather.com/" target="_blank">
#           For Advertising
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Products &amp; Services" data-gatext="AccuWeather APIs" href="https://developer.accuweather.com/" target="_blank">
#           AccuWeather APIs
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Products &amp; Services" data-gatext="Podcast" href="/podcast" target="_blank">
#           Podcast
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Products &amp; Services" data-gatext="RealFeel® and RealFeel Shade™" href="/en/realfeel-guide" target="_blank">
#           RealFeel® and RealFeel Shade™
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="footer-content-category">
#        <div class="footer-content-category-wrapper">
#         <div class="footer-content-category-header">
#          Apps &amp; Downloads
#         </div>
#         <div class="footer-category-section">
#          <a class="footer-category-section-link" data-gacategory="Apps &amp; Downloads" data-gatext="iPhone App" href="https://go.onelink.me/app/ef253ee1" target="_blank">
#           iPhone App
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Apps &amp; Downloads" data-gatext="Android App" href="https://go.onelink.me/app/85d14e58" target="_blank">
#           Android App
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Apps &amp; Downloads" data-gatext="See all Apps &amp; Downloads" href="https://7482826.hs-sites.com/premium-plus" target="_blank">
#           See all Apps &amp; Downloads
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="footer-content-category">
#        <div class="footer-content-category-wrapper">
#         <div class="footer-content-category-header">
#          Subscription Services
#         </div>
#         <div class="footer-category-section">
#          <a class="footer-category-section-link" data-gacategory="Subscription Services" data-gatext="AccuWeather Premium" href="https://wwwl.accuweather.com/premium_login.php" target="_blank">
#           AccuWeather Premium
#          </a>
#          <a class="footer-category-section-link" data-gacategory="Subscription Services" data-gatext="AccuWeather Professional" href="https://wwwl.accuweather.com/pro_login.php" target="_blank">
#           AccuWeather Professional
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="footer-content-category">
#        <div class="footer-content-category-wrapper">
#         <div class="footer-content-category-header">
#          More
#         </div>
#         <div class="footer-category-section">
#          <a class="footer-category-section-link" data-gacategory="More" data-gatext="AccuWeather Shop" href="https://www.accuweather.com/shop" target="_blank">
#           AccuWeather Shop
#          </a>
#          <a class="footer-category-section-link" data-gacategory="More" data-gatext="AccuWeather Ready" href="/en/accuweather-ready">
#           AccuWeather Ready
#          </a>
#          <a class="footer-category-section-link" data-gacategory="More" data-gatext="Business" href="/en/business">
#           Business
#          </a>
#          <a class="footer-category-section-link" data-gacategory="More" data-gatext="Health" href="/en/health-wellness">
#           Health
#          </a>
#             <path d="M18 0C8.053 0 0 8.053 0 18c0 9.893 7.987 17.933 17.867 18V23.653h-4.16V18.84h4.16v-3.547c0-4.12 2.52-6.36 6.186-6.36 1.76 0 3.267.134 3.707.187v4.307h-2.547c-2 0-2.386.946-2.386 2.346v3.067H27.6l-.627 4.813h-4.146v11.694C30.427 33.227 36 26.267 36 18c0-9.947-8.053-18-18-18Z" fill="#4167B2">
#             </path>
#            </g>
#           </svg>
#          </a>
#          <a class="social-link" data-gacategory="Twitter" data-galink="https://twitter.com/BreakingWeather" data-gatype="social" href="https://twitter.com/BreakingWeather" rel="noopener noreferrer" target="_blank">
#           <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/twitter.svg" height="32" viewbox="0 0 36 36" width="32">
#            <g fill="none" fill-rule="nonzero">
#             <path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#1DA1F3">
#             </path>
#             <path d="M26.904 14.316c.012.183.012.376.012.57 0 5.774-4.294 12.448-12.14 12.448a11.96 11.96 0 0 1-6.538-1.96c.33.046.672.058 1.014.058a8.424 8.424 0 0 0 5.296-1.868c-1.868-.034-3.44-1.298-3.987-3.04.262.056.524.079.798.079.387 0 .763-.057 1.127-.16-1.947-.398-3.428-2.163-3.428-4.293v-.057c.581.33 1.23.524 1.936.547a4.417 4.417 0 0 1-1.902-3.645c0-.797.205-1.549.581-2.198 2.107 2.654 5.25 4.385 8.792 4.567a4.717 4.717 0 0 1-.114-.99c0-2.415 1.914-4.374 4.26-4.374 1.23 0 2.335.535 3.109 1.378a8.26 8.26 0 0 0 2.71-1.06 4.3 4.3 0 0 1-1.879 2.415A8.4 8.4 0 0 0 29 12.05c-.535.877-1.264 1.64-2.096 2.266Z" fill="#FFF">
#             </path>
#            </g>
#           </svg>
#          </a>
#          <a class="social-link" data-gacategory="TV" data-galink="https://getaccuweather.tv" data-gatype="outbound" href="https://getaccuweather.tv/?utm_source=adc&amp;utm_medium=icon&amp;utm_campaign=footer" rel="noopener noreferrer" target="_blank">
#           <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/tv.svg" height="32" viewbox="0 0 36 36" width="32">
#            <g fill="none" fill-rule="evenodd">
#             <circle cx="18" cy="18" fill="#F05514" r="18">
#             </circle>
#             <g fill="#FFF">
#              <path d="M10.933 15.533H7.88v-2.08h8.44v2.08h-3.04v8.6h-2.347zM17.52 13.453h2.68l2.64 7h.027l2.68-7h2.52l-4.4 10.68h-1.88z">
#              </path>
#             </g>
#            </g>
#           </svg>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="footer-legalese">
#      <div class="footer-copyright">
#       <span>
#        © 2021 AccuWeather, Inc. "AccuWeather" and sun design are registered trademarks of AccuWeather, Inc. All Rights Reserved.
#       </span>
#      </div>
#      <div class="footer-terms" id="footer-terms">
#       <a data-ga="Terms of usage" href="/en/legal" target="_blank">
#        Terms of Use
#       </a>
#       |
#       <a data-ga="Privacy Policy" href="/en/privacy" target="_blank">
#        Privacy Policy
#       </a>
#       |
#       <a data-ga="Cookie Policy" href="/en/cookiepolicy" target="_blank">
#        Cookie Policy
#       </a>
#       |
#       <a data-ga="TAG Disclosure" href="/en/tag-publisher-sourcing-disclosure" target="_blank">
#        TAG Disclosure
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="glacier-ad unrendered oop" data-ad-type="oop" data-viewport="" id="oop">
#    </div>
#    <div class="glacier-ad unrendered interstitial" data-ad-type="interstitial" data-viewport="" id="interstitial">
#    </div>
#    <div class="privacy-policy-banner" data-banner-delay="0" data-banner-order="0" id="privacy-policy-banner">
#     <div class="banner-body">
#      <p>
#       We have updated our
#       <a href="/en/privacy" id="privacy-policy-banner-privacy-link" target="_blank">
#        Privacy Policy
#       </a>
#       and
#       <a href="/en/cookiepolicy" id="privacy-policy-banner-cookie-policy-link" target="_blank">
#        Cookie Policy
#       </a>
#       .
#      </p>
#      <div class="banner-button policy-accept">
#       I Understand
#      </div>
#     </div>
#    </div>
#    <div class="feedback-banner hide-mobile" id="feedback-banner">
#     <a class="feedback-banner-link" href="https://corporate.accuweather.com/company/contact/">
#      <span>
#       FEEDBACK
#      </span>
#      <svg class="icon-plus icon-plus" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#       <g fill="none" fill-rule="evenodd" stroke="#F05514" stroke-linecap="square" stroke-width="2">
#        <path d="M9 0v18M0 9h18">
#        </path>
#       </g>
#      </svg>
#     </a>
#    </div>
#   </div>
#   <script>
#    // Check for third party cookie support
# 		const thirdPartyIframe = document.createElement('iframe');
# 		thirdPartyIframe.setAttribute(
# 			'src',
# 			'https://www.awxcdn.com/adc/3rdpartycheck.html'
# 		);
# 		thirdPartyIframe.setAttribute('style', 'width:0;height:0;display:none');
# 		document.body.appendChild(thirdPartyIframe);
#   </script>
#   <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/city.three-day-desktop.bed6cbeaebf813654bbd.js">
#   </script>
#   <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/5.a0941fd70bb95b9486c4.js">
#   </script>
#   <script>
#    function removeWindowLoadClass() {
# 			const revcontentLoading = document.querySelectorAll('.revcontent.window-loading');
#
# 			if (revcontentLoading) {
# 				revcontentLoading.forEach((revcontentAd) => {
# 					revcontentAd.classList.remove('window-loading');
# 				})
# 			}
# 		};
#
# 		function callRevcontentScript() {
# 			const s = document.createElement("script");
# 			el = document.getElementsByTagName("script")[0];
# 			s.defer = true;
# 			s.src = "https://assets.revcontent.com/master/delivery.js";
# 			el.parentNode.insertBefore(s, el);
#
# 			removeWindowLoadClass();
#         };
#
#         window.addEventListener('load', callRevcontentScript);
#   </script>
#   <script>
#    var _comscore = _comscore || [];
# 		_comscore.push({"c1":"2","c2":"6005068"});
#
# 		const isCountryEEA = false;
#
# 		if(isCountryEEA){
# 			const consentCookieName = 'awxconsent';
#
# 			const timer = setInterval(() => {
# 				const consent = document.cookie.match('(^|;)\\s*' + consentCookieName + '\\s*=\\s*([^;]+)')?.pop() || '';
#
# 				if(consent == 1){
# 					callComScore();
# 					clearInterval(timer);
# 				}
# 			}, 5000);
# 		}
# 		else{
# 			callComScore();
# 		}
#
# 		function callComScore(){
# 			var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# 			s.src = "https://sb.scorecardresearch.com/internal-cs/default/beacon.js";
# 			el.parentNode.insertBefore(s, el);
# 		}
#   </script>
#   <noscript>
#    <img alt="ComScore" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6005068&amp;cv=3.6&amp;cj=1"/>
#   </noscript>
#   <script>
#    var isPushlyEnabled = false;
#   </script>
#   <script async="" id="bt_bootstrap_2.0" src="//accuweather-com.videoplayerhub.com/btTag.js?w=5760049299324928">
#   </script>
#   <noscript>
#    <img src="https://www.accuweather.com/akam/13/pixel_c188ed4?a=dD04MWQxYTI5Zjk0NzI5ZDRiMDk0MTgwMTcxMWI5MmEzNTJjYWNiODM1JmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/>
#   </noscript>
#  </body>
# </html>

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191"
headers = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36"}

resp = requests.get(url, headers = headers)

soup = BeautifulSoup(resp.content)
# print(soup.body.div.h1.prettify())
print(soup.div.div.prettify())
# print(soup.body.div.div.div.prettify())
# Out:
# <div class="nfl-header">
#  <div class="header-outer">
#   <div class="header-inner">
#    <a class="header-logo" href="/">
#     <svg data-eager="" height="24" viewbox="0 0 189 27" width="168" xmlns="http://www.w3.org/2000/svg">
#      <g fill="none">
#       <path d="M183.058 22.739v-6.864c0-1.4.293-2.342.879-2.83.585-.488 1.561-.716 2.863-.716h1.269v-3.09h-1.074c-.976 0-1.822.13-2.505.422a4.054 4.054 0 0 0-1.66 1.237l-.65-1.66h-2.44v13.5h3.318zM171.28 11.743c.944 0 1.66.26 2.148.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.195zm2.766 6.93c-.228.487-.553.878-.976 1.138-.423.293-.944.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.228c-1.92 0-3.449.618-4.588 1.887-1.138 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.456 2.668a5.877 5.877 0 0 0 1.269 2.082 5.83 5.83 0 0 0 2.017 1.366c.814.325 1.692.488 2.7.488h.229c1.269 0 2.342-.26 3.253-.748s1.66-1.236 2.213-2.245l-2.896-1.464zm-20.271 4.066v-7.873c.033-.91.26-1.659.716-2.244.455-.586 1.139-.879 1.985-.879h.325c.748 0 1.334.228 1.757.716.456.455.65 1.236.65 2.31v8.002h3.32v-8.588c0-1.594-.423-2.863-1.302-3.838-.878-.976-2.017-1.464-3.481-1.464h-.39c-.717 0-1.4.13-2.018.423a5.332 5.332 0 0 0-1.627 1.17V3.84h-3.319v18.9h3.384zm-8.688-2.96c-.227-.196-.325-.554-.325-1.074v-6.799h3.254V9.239h-3.254v-2.96h-2.83l-.359 2.96h-2.212v2.667h2.115v6.831c0 1.236.293 2.212.878 2.928.586.716 1.595 1.074 2.994 1.074h2.635V20.07h-1.92c-.455 0-.78-.098-.976-.293zm-13.828.52c-.683 0-1.204-.13-1.562-.39-.358-.26-.553-.651-.553-1.14v-.097c0-.488.195-.91.618-1.236.39-.325 1.106-.488 2.148-.488h2.472v.488c0 .976-
#       </path>
#       <path d="M13.438 22.771c-5.14 0-9.338-4.196-9.338-9.336 0-5.14 4.197-9.304 9.338-9.304 5.141 0 9.306 4.197 9.306 9.304 0 5.172-4.165 9.336-9.306 9.336zm13.438-9.369-3.058-2.765 1.236-3.936-4.035-.878-.878-4.034-3.937 1.269L13.406 0 10.64 3.058 6.703 1.822l-.879 4.033-4.034.879 1.269 3.936L0 13.467l3.059 2.766-1.237 3.936 4.035.878.878 4.034 3.937-1.269 2.799 3.058 2.765-3.058 3.937 1.236.879-4.034 4.035-.91-1.27-3.937 3.06-2.765z" fill="#F05514">
#       </path>
#       <path d="M7.549 7.58a8.328 8.328 0 0 1 11.779 0 8.323 8.323 0 0 1 0 11.775 8.328 8.328 0 0 1-11.78 0c-3.253-3.253-3.253-8.555 0-11.775" fill="#F05514">
#       </path>
#      </g>
#     </svg>
#    </a>
#    <a class="header-city-link" href="/en/kz/almaty/222191/weather-forecast/222191">
#     <h1 class="header-loc">
#      Almaty, Almaty
#     </h1>
#     <span class="header-temp">
#      16°
#      <span class="unit">
#       C
#      </span>
#     </span>
#     <svg class="header-weather-icon" data-src="/images/weathericons/1.svg" height="27" viewbox="0 0 288 288" width="27">
#      <g fill="none" fill-rule="evenodd" stroke="#FF8700" stroke-width="9.6">
#       <path d="M144 0v48M144 240v48M0 144h48M211.872 76.128l33.936-33.936M245.808 245.808l-33.936-33.936M76.128 76.128 42.192 42.192">
#       </path>
#       <circle cx="144" cy="144" r="76.8">
#       </circle>
#       <path d="m76.128 211.872-33.936 33.936M240 144h48">
#       </path>
#      </g>
#     </svg>
#    </a>
#    <div class="pull-right">
#     <div class="header-search-bar search-bar">
#      <div class="searchbar-inner">
#       <svg class="icon-search" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#        <path d="M7.186 13.554c-3.462 0-6.303-2.869-6.303-6.359C.883 3.681 3.724.837 7.186.837c3.437 0 6.278 2.844 6.278 6.358 0 3.49-2.865 6.359-6.278 6.359zm5.323-1.602a7.176 7.176 0 0 0 1.815-4.757c0-3.968-3.2-7.195-7.138-7.195C3.223 0 0 3.227 0 7.195c0 3.944 3.223 7.171 7.186 7.171a7.058 7.058 0 0 0 4.75-1.84L17.427 18l.573-.55-5.49-5.498z" transform="translate(3 3)">
#        </path>
#       </svg>
#       <form action="/en/search-locations" class="search-form" method="GET">
#        <input autocomplete="off" class="search-input" name="query" placeholder="Search" type="text"/>
#       </form>
#       <svg class="clear-icon close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#        <g fill-rule="evenodd" transform="translate(-1 -1)">
#         <rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2">
#         </rect>
#         <rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2">
#         </rect>
#        </g>
#       </svg>
#       <div class="search-options">
#        <div class="dropdown-legacy left-bar">
#         <div class="displayed-item">
#          <span>
#           Location
#          </span>
#          <svg aria-labelledby="chevronSVG" class="icon-chevron arrow" height="6" role="img" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
#           <title id="chevronSVG">
#            Chevron down
#           </title>
#           <path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z">
#           </path>
#          </svg>
#         </div>
#         <div class="items">
#          <a class="item active" value="/en/search-locations">
#           <span>
#            Location
#           </span>
#           <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z">
#            </path>
#            <use fill="#000" fill-rule="evenodd">
#            </use>
#           </svg>
#          </a>
#          <a class="item" value="/en/search-news">
#           <span>
#            News
#           </span>
#           <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z">
#            </path>
#            <use fill="#000" fill-rule="evenodd">
#            </use>
#           </svg>
#          </a>
#          <a class="item" value="/en/search-video">
#           <span>
#            Videos
#           </span>
#           <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z">
#            </path>
#            <use fill="#000" fill-rule="evenodd">
#            </use>
#           </svg>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="search-bar-dropdown">
#       <div class="use-current-location">
#        <svg class="icon-gps gps-icon" height="16" viewbox="0 0 14 18" width="14" xmlns="http://www.w3.org/2000/svg">
#         <g fill-opacity="0.995941" fill-rule="evenodd" id="Symbols" stroke="none" stroke-width="1">
#          <g id="ICONS-/-Menu-/-GPS">
#           <polygon id="Triangle" points="9.44615242 -1.13878407 15.4461524 15.8612159 9.44615242 12.4612159 3.44615242 15.8612159" transform="translate(9.446152, 7.361216) rotate(-330.000000) translate(-9.446152, -7.361216) ">
#           </polygon>
#          </g>
#         </g>
#        </svg>
#        <span>
#         Use Current Location
#        </span>
#       </div>
#       <div class="recent-locations-dropdown">
#        <div class="recent-title">
#         Recent
#        </div>
#        <a class="recent-location" data-fetch="false" data-location-key="222191" href="/web-api/three-day-redirect?key=222191&amp;target=">
#         <div class="recent-location__title-wrapper">
#          <p class="recent-location__name">
#           Almaty
#          </p>
#          <p class="recent-location__admin">
#           Almaty
#          </p>
#         </div>
#         <svg class="recent-location__icon" data-src="/images/weathericons/1.svg" height="32" viewbox="0 0 288 288" width="32">
#          <g fill="none" fill-rule="evenodd" stroke="#FF8700" stroke-width="9.6">
#           <path d="M144 0v48M144 240v48M0 144h48M211.872 76.128l33.936-33.936M245.808 245.808l-33.936-33.936M76.128 76.128 42.192 42.192">
#           </path>
#           <circle cx="144" cy="144" r="76.8">
#           </circle>
#           <path d="m76.128 211.872-33.936 33.936M240 144h48">
#           </path>
#          </g>
#         </svg>
#         <span class="recent-location__temp">
#          16°
#         </span>
#        </a>
#       </div>
#       <div class="search-results">
#        <div class="results-container">
#        </div>
#       </div>
#       <div class="search-results no-search-result hidden">
#        <div class="results-container">
#         <div class="search-bar-result search-result no-result">
#          <div class="no-result-headline">
#           No results found.
#          </div>
#          <div class="no-result-text">
#           Try searching for a city, zip code or point of interest.
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <svg class="hamburger-button icon-hamburger" data-qa="navigationMenu" height="18" viewbox="0 0 24 24" width="18" xmlns="http://www.w3.org/2000/svg">
#      <defs>
#       <path d="M10 12v1H0v-1h10zm6-6v1H0V6h16zm0-6v1H0V0h16z" id="svghamburger">
#       </path>
#      </defs>
#      <use fill="#FFF" fill-rule="evenodd" transform="matrix(-1 0 0 1 20 6)" xlink:href="#svghamburger">
#      </use>
#     </svg>
#     <svg class="close-button close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#      <g fill-rule="evenodd" transform="translate(-1 -1)">
#       <rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2">
#       </rect>
#       <rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2">
#       </rect>
#      </g>
#     </svg>
#    </div>
#   </div>
#  </div>
#  <div class="header-menu">
#   <div class="settings-link">
#    <a href="/en/settings">
#     <svg class="icon-settings" fill="#FFF" height="25" viewbox="0 0 24 25" width="24" xmlns="http://www.w3.org/2000/svg">
#      <path d="M13.677.107l.871 2.674c.775.225 1.549.483 2.162.902l2.58-1.32 2.452 2.447-1.29 2.578c.354.612.645 1.353.87 2.094l2.678.902v3.414l-2.645.838c-.258.773-.549 1.578-.903 2.255l1.29 2.48-2.452 2.449-2.58-1.224c-.645.386-1.387.676-2.162.902l-.87 2.609h-3.42l-.903-2.61c-.742-.225-1.484-.482-2.161-.934L4.742 21.82 2.29 19.372l1.29-2.449c-.386-.676-.677-1.45-.903-2.255L0 13.798v-3.447l2.71-.902c.193-.74.451-1.481.87-2.094L2.29 4.843l2.452-2.449 2.452 1.289c.677-.387 1.419-.677 2.16-.902l.904-2.674h3.42zm-.838 1.128h-1.807l-.806 2.448-.549.193c-.677.194-1.354.419-1.935.773l-.548.29-2.29-1.16L3.58 5.1l1.225 2.384-.354.548c-.323.483-.581 1.127-.71 1.74l-.13.612-2.515.805v1.804l2.451.805.194.58c.193.677.42 1.385.774 1.965l.29.548-1.16 2.287L4.967 20.5l2.322-1.16.549.355c.58.354 1.226.612 1.903.773l.548.193.775 2.32h1.838l.774-2.417.581-.128c.677-.194 1.323-.42 1.903-.741l.484-.322 2.42 1.127 1.322-1.32-1.161-2.288.29-.483c.323-.645.58-1.353.774-2.062l.194-.58 2.42-.74V11.19l-2.452-.805-.194-.548c-.193-.677-.42-1.32-.742-1.836l-.29-.548 1.161-2.384-1.322-1.353-2.388 1.256-.548-.354a7.5 7.5 0 00-1.903-.74l-.58-.194-.807-2.448zm-.871 5.38c3.032 0 5.548 2.448 5.548 5.508 0 3.028-2.516 5.541-5.548 5.541-3.065 0-5.516-2.545-5.516-5.54a5.49 5.49 0 015.516-5.51zm0 1.063c-2.323 0-4.355 2.093-4.355 4.445 0 2.352 2.032 4.446 4.355 4.446 2.322 0 4.387-2.126 4.387-4.446 0-2.352-2.065-4.445-4.387-4.445z">
#      </path>
#     </svg>
#     settings
#    </a>
#    <svg class="close-button close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#     <g fill-rule="evenodd" transform="translate(-1 -1)">
#      <rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2">
#      </rect>
#      <rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2">
#      </rect>
#     </g>
#    </svg>
#   </div>
#   <div class="header-loc-weather">
#    Almaty, Almaty Weather
#   </div>
#   <a class="header-link active" data-page-id="today" href="/en/kz/almaty/222191/weather-forecast/222191">
#    Today
#   </a>
#   <a class="header-link nav-red-dot hidden tropical-link" data-page-id="local_{stormName}_tracker" href="/en/kz/almaty/222191/tropical-weather-forecast/222191?eventkey={eventkey}">
#    Local {stormName} Tracker
#   </a>
#   <a class="header-link" data-page-id="hourly" href="/en/kz/almaty/222191/hourly-weather-forecast/222191">
#    Hourly
#   </a>
#   <a class="header-link" data-page-id="daily" href="/en/kz/almaty/222191/daily-weather-forecast/222191">
#    Daily
#   </a>
#   <a class="header-link" data-page-id="radar" href="/en/kz/almaty/222191/weather-radar/222191">
#    Radar
#   </a>
#   <a class="header-link" data-page-id="minutecast" href="/en/kz/almaty/222191/minute-weather-forecast/222191">
#    MinuteCast
#   </a>
#   <a class="header-link" data-page-id="monthly" href="/en/kz/almaty/222191/october-weather/222191">
#    Monthly
#   </a>
#   <a class="header-link" data-page-id="air_quality" href="/en/kz/almaty/222191/air-quality-index/222191">
#    Air Quality
#   </a>
#   <a class="header-link" data-page-id="health_and_activities" href="/en/kz/almaty/222191/health-activities/222191">
#    Health &amp; Activities
#   </a>
#   <div class="more-cta-links">
#    <h2 class="more-cta-title">
#     Around the Globe
#    </h2>
#    <a class="cta-link" data-page-id="hurricane_tracker" href="/en/hurricane">
#     <h3 class="cta-text">
#      Hurricane Tracker
#     </h3>
#     <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#      <defs>
#       <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#       </path>
#      </defs>
#      <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#      </use>
#     </svg>
#    </a>
#    <a class="cta-link" data-page-id="radar_and_maps" href="/en/kz/almaty/weather-radar">
#     <h3 class="cta-text">
#      Radar &amp; Maps
#     </h3>
#     <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#      <defs>
#       <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#       </path>
#      </defs>
#      <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#      </use>
#     </svg>
#    </a>
#    <div class="sublink-container">
#     <div class="sublink-header">
#      <div class="sublink-title">
#       News
#      </div>
#      <svg class="icon-chevron chevron-icon down" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
#       <path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z">
#       </path>
#      </svg>
#     </div>
#     <a class="cta-link" data-page-id="news_and_features" href="/en/weather-news">
#      <h3 class="cta-text">
#       News &amp; Features
#      </h3>
#      <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#       <defs>
#        <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#        </path>
#       </defs>
#       <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#       </use>
#      </svg>
#     </a>
#     <a class="cta-link" data-page-id="astronomy" href="/en/space-news">
#      <h3 class="cta-text">
#       Astronomy
#      </h3>
#      <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#       <defs>
#        <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#        </path>
#       </defs>
#       <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#       </use>
#      </svg>
#     </a>
#     <a class="cta-link" data-page-id="business" href="/en/business">
#      <h3 class="cta-text">
#       Business
#      </h3>
#      <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#       <defs>
#        <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#        </path>
#       </defs>
#       <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#       </use>
#      </svg>
#     </a>
#     <a class="cta-link" data-page-id="climate" href="/en/climate">
#      <h3 class="cta-text">
#       Climate
#      </h3>
#      <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#       <defs>
#        <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#        </path>
#       </defs>
#       <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#       </use>
#      </svg>
#     </a>
#     <a class="cta-link" data-page-id="health" href="/en/health-wellness">
#      <h3 class="cta-text">
#       Health
#      </h3>
#      <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#       <defs>
#        <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#        </path>
#       </defs>
#       <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#       </use>
#      </svg>
#     </a>
#     <a class="cta-link" data-page-id="recreation" href="/en/leisure-recreation">
#      <h3 class="cta-text">
#       Recreation
#      </h3>
#      <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#       <defs>
#        <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#        </path>
#       </defs>
#       <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#       </use>
#      </svg>
#     </a>
#     <a class="cta-link" data-page-id="sports" href="/en/sports">
#      <h3 class="cta-text">
#       Sports
#      </h3>
#      <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#       <defs>
#        <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#        </path>
#       </defs>
#       <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#       </use>
#      </svg>
#     </a>
#     <a class="cta-link" data-page-id="travel" href="/en/travel">
#      <h3 class="cta-text">
#       Travel
#      </h3>
#      <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#       <defs>
#        <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#        </path>
#       </defs>
#       <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#       </use>
#      </svg>
#     </a>
#    </div>
#    <a class="cta-link" data-page-id="video" href="/en/videos">
#     <h3 class="cta-text">
#      Video
#     </h3>
#     <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#      <defs>
#       <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#       </path>
#      </defs>
#      <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#      </use>
#     </svg>
#    </a>
#    <a class="cta-link" data-page-id="podcasts" href="/podcast">
#     <h3 class="cta-text">
#      Podcasts
#     </h3>
#     <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
#      <defs>
#       <path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a">
#       </path>
#      </defs>
#      <use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a">
#      </use>
#     </svg>
#    </a>
#   </div>
#  </div>
# </div>

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191"
headers = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36"}

resp = requests.get(url, headers = headers)

soup = BeautifulSoup(resp.content)
print(soup.find("a"))
# Out:
# <a class="header-logo" href="/">
# <svg data-eager="" height="24" viewbox="0 0 189 27" width="168" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M183.058 22.739v-6.864c0-1.4.293-2.342.879-2.83.585-.488 1.561-.716 2.863-.716h1.269v-3.09h-1.074c-.976 0-1.822.13-2.505.422a4.054 4.054 0 0 0-1.66 1.237l-.65-1.66h-2.44v13.5h3.318zM171.28 11.743c.944 0 1.66.26 2.148.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.195zm2.766 6.93c-.228.487-.553.878-.976 1.138-.423.293-.944.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.228c-1.92 0-3.449.618-4.588 1.887-1.138 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.456 2.668a5.877 5.877 0 0 0 1.269 2.082 5.83 5.83 0 0 0 2.017 1.366c.814.325 1.692.488 2.7.488h.229c1.269 0 2.342-.26 3.253-.748s1.66-1.236 2.213-2
.455-.684-1.236-.684-2.31V9.206h-3.253v.033zm-3.645.553c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3.319-.78.878-.521 1.561-1.27 2.082-2.31l-2.733-1.53a3.17 3.17 0 0 1-.976 1.27c-.423.325-.976.487-1.692.487h-.228c-1.041 0-1.79-.325-2.278-.943-.488-.618-.715-1.431-.715-2.44V15.16c0-1.008.227-1.822.715-2.44.488-.618 1.237-.943 2.278-.943h.228c.716 0 1.301.163 1.724.488.423.325.749.78.976 1.334l2.864-1.367c-.423-1.008-1.107-1.854-2.018-2.44zm-13.308 0c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3 ...
# </a>

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191"
headers = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36"}

resp = requests.get(url, headers = headers)

soup = BeautifulSoup(resp.content)
print(soup.find_all("div"))
# Out:
# [<div class="template-root" style="display:none">
# <div class="nfl-header">
# <div class="header-outer">
# <div class="header-inner">
# <a class="header-logo" href="/">
# <svg data-eager="" height="24" viewbox="0 0 189 27" width="168" xmlns="http://www.w3.org/2000/svg"><g fill="none"><path d="M183.058 22.739v-6.864c0-1.4.293-2.342.879-2.83.585-.488 1.561-.716 2.863-.716h1.269v-3.09h-1.074c-.976 0-1.822.13-2.505.422a4.054 4.054 0 0 0-1.66 1.237l-.65-1.66h-2.44v13.5h3.318zM171.28 11.743c.944 0 1.66.26 2.148.814.488.553.748 1.268.813 2.147h-6.117c.065-.911.326-1.627.814-2.147.488-.553 1.204-.814 2.147-.814h.195zm2.766 6.93c-.228.487-.553.878-.976 1.138-.423.293-.944.423-1.627.423h-.228c-1.008 0-1.757-.293-2.277-.846-.52-.553-.814-1.301-.879-2.18h9.469v-1.366c0-2.114-.553-3.806-1.66-5.042-1.106-1.269-2.635-1.887-4.555-1.887h-.228c-1.92 0-3.449.618-4.588 1.887-1.138 1.236-1.692 2.863-1.692 4.847v.878c0 .976.163 1.855.456 2.668a5.877 5.877 0 0 0 1.269 2.082 5.83 5.83 0 0 0 2.017 1.366c.814.325 1.692.488 2.7.488h.229c1.269 0 2.342-.26 3.253-.748s1.66-1.236 2.213-2.245l-2.896-1.464zm-20.271 4.066v-7.873c.033-.91.26-1.659.716-2.244.455-.586 1.139-.879 1.985-.879h.325c.748 0 1.334.228 1.757.716.456.455.65 1.236.65 2.31v8.002h3.32v-8.588c0-1.594-.423-2.863-1.302-3.838-.878-.976-2.017-1.464-3.481-1.464h-.39c-.717 0-1.4.13-2.018.423a5.332 5.332 0 0 0-1.627 1.17V3.84h-3.319v18.9h3.384zm-8.688-2.96c-.227-.196
325-.976.487-1.692.487h-.228c-1.041 0-1.79-.325-2.278-.943-.488-.618-.715-1.431-.715-2.44V15.16c0-1.008.227-1.822.715-2.44.488-.618 1.237-.943 2.278-.943h.228c.716 0 1.301.163 1.724.488.423.325.749.78.976 1.334l2.864-1.367c-.423-1.008-1.107-1.854-2.018-2.44zm-13.308 0c-.91-.586-2.082-.879-3.546-.879h-.228c-1.92 0-3.449.553-4.588 1.692-1.139 1.138-1.692 2.635-1.692 4.522v1.724c0 1.886.553 3.415 1.692 4.521 1.139 1.139 2.636 1.692 4.588 1.692h.228c1.334 0 2.44-.26 3 ...
# </a>
# <a class="header-city-link" href="/en/kz/almaty/222191/weather-forecast/222191">
# <h1 class="header-loc">Almaty, Almaty</h1>
# <span class="header-temp">
# 						18°
# 						<span class="unit">C</span>
# </span>
# <svg class="header-weather-icon" data-src="/images/weathericons/1.svg" height="27" viewbox="0 0 288 288" width="27"><g fill="none" fill-rule="evenodd" stroke="#FF8700" stroke-width="9.6"><path d="M144 0v48M144 240v48M0 144h48M211.872 76.128l33.936-33.936M245.808 245.808l-33.936-33.936M76.128 76.128 42.192 42.192"></path><circle cx="144" cy="144" r="76.8"></circle><path d="m76.128 211.872-33.936 33.936M240 144h48"></path></g></svg>
# </a>
# <div class="pull-right">
# <div class="header-search-bar search-bar">
# <div class="searchbar-inner">
# <svg class="icon-search" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.186 13.554c-3.462 0-6.303-2.869-6.303-6.359C.883 3.681 3.724.837 7.186.837c3.437 0 6.278 2.844 6.278 6.358 0 3.49-2.865 6.359-6.278 6.359zm5.323-1.602a7.176 7.176 0 0 0 1.815-4.757c0-3.968-3.2-7.195-7.138-7.195C3.223 0 0 3.227 0 7.195c0 3.944 3.223 7.171 7.186 7.171a7.058 7.058 0 0 0 4.75-1.84L17.427 18l.573-.55-5.49-5.498z" transform="translate(3 3)"></path></svg>
# <form action="/en/search-locations" class="search-form" method="GET">
# <input autocomplete="off" class="search-input" name="query" placeholder="Search" type="text"/>
# </form>
# <svg class="clear-icon close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# <div class="search-options">
# <div class="dropdown-legacy left-bar">
# <div class="displayed-item">
# <span>
# 			Location
# 		</span>
# <svg aria-labelledby="chevronSVG" class="icon-chevron arrow" height="6" role="img" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
# <title id="chevronSVG">Chevron down</title>
# <path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path>
# </svg>
# </div>
# <div class="items">
# <a class="item active" value="/en/search-locations">
# <span>Location</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-news">
# <span>News</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# <a class="item" value="/en/search-video">
# <span>Videos</span>
# <svg alt="" class="item-icon icon-check" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M7.832 17.496L2.142 11.9.205 13.792l7.627 7.503L24.205 5.188l-1.924-1.893z"></path><use fill="#000" fill-rule="evenodd"></use></svg>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="search-bar-dropdown">
# <div class="use-current-location">
# <svg class="icon-gps gps-icon" height="16" viewbox="0 0 14 18" width="14" xmlns="http://www.w3.org/2000/svg"><g fill-opacity="0.995941" fill-rule="evenodd" id="Symbols" stroke="none" stroke-width="1"><g id="ICONS-/-Menu-/-GPS"><polygon id="Triangle" points="9.44615242 -1.13878407 15.4461524 15.8612159 9.44615242 12.4612159 3.44615242 15.8612159" transform="translate(9.446152, 7.361216) rotate(-330.000000) translate(-9.446152, -7.361216) "></polygon></g></g></svg>
# <span>Use Current Location</span>
# </div>
# <div class="recent-locations-dropdown">
# <div class="recent-title">Recent</div>
# <a class="recent-location" data-fetch="false" data-location-key="222191" href="/web-api/three-day-redirect?key=222191&amp;target=">
# <div class="recent-location__title-wrapper">
# <p class="recent-location__name">Almaty</p>
# <p class="recent-location__admin">Almaty</p>
# </div>
# <svg class="recent-location__icon" data-src="/images/weathericons/1.svg" height="32" viewbox="0 0 288 288" width="32"><g fill="none" fill-rule="evenodd" stroke="#FF8700" stroke-width="9.6"><path d="M144 0v48M144 240v48M0 144h48M211.872 76.128l33.936-33.936M245.808 245.808l-33.936-33.936M76.128 76.128 42.192 42.192"></path><circle cx="144" cy="144" r="76.8"></circle><path d="m76.128 211.872-33.936 33.936M240 144h48"></path></g></svg>
# <span class="recent-location__temp">18°</span>
# </a>
# </div>
# <div class="search-results">
# <div class="results-container"></div>
# </div>
# <div class="search-results no-search-result hidden">
# <div class="results-container">
# <div class="search-bar-result search-result no-result">
# <div class="no-result-headline">No results found.</div>
# <div class="no-result-text">Try searching for a city, zip code or point of interest.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <svg class="hamburger-button icon-hamburger" data-qa="navigationMenu" height="18" viewbox="0 0 24 24" width="18" xmlns="http://www.w3.org/2000/svg">
# <defs>
# <path d="M10 12v1H0v-1h10zm6-6v1H0V6h16zm0-6v1H0V0h16z" id="svghamburger"></path>
# </defs>
# <use fill="#FFF" fill-rule="evenodd" transform="matrix(-1 0 0 1 20 6)" xlink:href="#svghamburger"></use></svg>
# <svg class="close-button close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# </div>
# </div>
# </div>
# <div class="header-menu">
# <div class="settings-link">
# <a href="/en/settings">
# <svg class="icon-settings" fill="#FFF" height="25" viewbox="0 0 24 25" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M13.677.107l.871 2.674c.775.225 1.549.483 2.162.902l2.58-1.32 2.452 2.447-1.29 2.578c.354.612.645 1.353.87 2.094l2.678.902v3.414l-2.645.838c-.258.773-.549 1.578-.903 2.255l1.29 2.48-2.452 2.449-2.58-1.224c-.645.386-1.387.676-2.162.902l-.87 2.609h-3.42l-.903-2.61c-.742-.225-1.484-.482-2.161-.934L4.742 21.82 2.29 19.372l1.29-2.449c-.386-.676-.677-1.45-.903-2.255L0 13.798v-3.447l2.71-.902c.193-.74.451-1.481.87-2.094L2.29 4.843l2.452-2.449 2.452 1.289c.677-.387 1.419-.677 2.16-.902l.904-2.674h3.42zm-.838 1.128h-1.807l-.806 2.448-.549.193c-.677.194-1.354.419-1.935.773l-.548.29-2.29-1.16L3.58 5.1l1.225 2.384-.354.548c-.323.483-.581 1.127-.71 1.74l-.13.612-2.515.805v1.804l2.451.805.194.58c.193.677.42 1.385.774 1.965l.29.548-1.16 2.287L4.967 20.5l2.322-1.16.549.355c.58.354 1.226.612 1.903.773l.548.193.775 2.32h1.838l.774-2.417.581-.128c.677-.194 1.323-.42 1.903-.741l.484-.322 2.42 1.127 1.322-1.32-1.161-2.288.29-.483c.323-.645.58-1.353.774-2.062l.194-.58 2.42-.74V11.19l-2.452-.805-.194-.548c-.193-.677-.42-1.32-.742-1.836l-.29-.548 1.161-2.384-1.322-1.353-2.388 1.256-.548-.354a7.5 7.5 0 00-1.903-.74l-.58-.194-.807-2.448zm-.871 5.38c3.032 0 5.548 2.448 5.548 5.508 0 3.028-2.516 5.541-5.548 5.541-3.065 0-5.516-2.545-5.516-5.54a5.49 5.49 0 015.516-5.51zm0 1.063c-2.323 0-4.355 2.093-4.355 4.445 0 2.352 2.032 4.446 4.355 4.446 2.322 0 4.387-2.126 4.387-4.446 0-2.352-2.065-4.445-4.387-4.445z"></path></svg>
# 				settings
# 			</a>
# <svg class="close-button close-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><g fill-rule="evenodd" transform="translate(-1 -1)"><rect height="24" rx="1" transform="rotate(45 10 10)" width="2" x="9" y="-2"></rect><rect height="24" rx="1" transform="rotate(-45 10 10)" width="2" x="9" y="-2"></rect></g></svg>
# </div>
# <div class="header-loc-weather">Almaty, Almaty Weather</div>
# <a class="header-link active" data-page-id="today" href="/en/kz/almaty/222191/weather-forecast/222191">Today</a>
# <a class="header-link nav-red-dot hidden tropical-link" data-page-id="local_{stormName}_tracker" href="/en/kz/almaty/222191/tropical-weather-forecast/222191?eventkey={eventkey}">Local {stormName} Tracker</a>
# <a class="header-link" data-page-id="hourly" href="/en/kz/almaty/222191/hourly-weather-forecast/222191">Hourly</a>
# <a class="header-link" data-page-id="daily" href="/en/kz/almaty/222191/daily-weather-forecast/222191">Daily</a>
# <a class="header-link" data-page-id="radar" href="/en/kz/almaty/222191/weather-radar/222191">Radar</a>
# <a class="header-link" data-page-id="minutecast" href="/en/kz/almaty/222191/minute-weather-forecast/222191">MinuteCast</a>
# <a class="header-link" data-page-id="monthly" href="/en/kz/almaty/222191/october-weather/222191">Monthly</a>
# <a class="header-link" data-page-id="air_quality" href="/en/kz/almaty/222191/air-quality-index/222191">Air Quality</a>
# <a class="header-link" data-page-id="health_and_activities" href="/en/kz/almaty/222191/health-activities/222191">Health &amp; Activities</a>
# <div class="more-cta-links">
# <h2 class="more-cta-title">
# 		Around the Globe
# 	</h2>
# <a class="cta-link" data-page-id="hurricane_tracker" href="/en/hurricane">
# <h3 class="cta-text">Hurricane Tracker</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="radar_and_maps" href="/en/kz/almaty/weather-radar">
# <h3 class="cta-text">Radar &amp; Maps</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <div class="sublink-container">
# <div class="sublink-header">
# <div class="sublink-title">News</div>
# <svg class="icon-chevron chevron-icon down" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# </div>
# <a class="cta-link" data-page-id="news_and_features" href="/en/weather-news">
# <h3 class="cta-text">News &amp; Features</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="astronomy" href="/en/space-news">
# <h3 class="cta-text">Astronomy</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="business" href="/en/business">
# <h3 class="cta-text">Business</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="climate" href="/en/climate">
# <h3 class="cta-text">Climate</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="health" href="/en/health-wellness">
# <h3 class="cta-text">Health</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="recreation" href="/en/leisure-recreation">
# <h3 class="cta-text">Recreation</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="sports" href="/en/sports">
# <h3 class="cta-text">Sports</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="travel" href="/en/travel">
# <h3 class="cta-text">Travel</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </div>
# <a class="cta-link" data-page-id="video" href="/en/videos">
# <h3 class="cta-text">Video</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-page-id="podcasts" href="/podcast">
# <h3 class="cta-text">Podcasts</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </div>
# </div>
# </div>
# <div class="header-placeholder"></div>
# <div class="page-subnav">
# <div class="subnav secondary-nav" data-gatype="city">
# <div class="overflow overflow-left" data-qa="leftArrow">
# <svg class="arrow chevron-icon left" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# </div>
# <div class="overflow overflow-right" data-qa="rightArrow">
# <svg class="arrow chevron-icon right" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# </div>
# <div class="subnav-items">
# <a class="subnav-item active" data-gaid="now" data-qa="now" href="/en/kz/almaty/222191/weather-forecast/222191">
# <h2>Today</h2>
# </a>
# <a class="subnav-item" data-gaid="hourly" data-qa="hourly" href="/en/kz/almaty/222191/hourly-weather-forecast/222191">
# <span>Hourly</span>
# </a>
# <a class="subnav-item" data-gaid="daily" data-qa="daily" href="/en/kz/almaty/222191/daily-weather-forecast/222191">
# <span>Daily</span>
# </a>
# <a class="subnav-item" data-gaid="radar" data-qa="radar" href="/en/kz/almaty/222191/weather-radar/222191">
# <span>Radar</span>
# </a>
# <a class="subnav-item" data-gaid="minutecast" data-qa="minutecast" href="/en/kz/almaty/222191/minute-weather-forecast/222191">
# <span>MinuteCast</span>
# </a>
# <a class="subnav-item" data-gaid="monthly" data-qa="monthly" href="/en/kz/almaty/222191/october-weather/222191">
# <span>Monthly</span>
# </a>
# <a class="subnav-item" data-gaid="airQuality" data-qa="airQuality" href="/en/kz/almaty/222191/air-quality-index/222191">
# <span>Air Quality</span>
# </a>
# <a class="subnav-item" data-gaid="lifestyles" data-qa="lifestyles" href="/en/kz/almaty/222191/health-activities/222191">
# <span>Health &amp; Activities</span>
# </a>
# <div class="subnav-item filler"></div>
# </div>
# </div>
# </div>
# <div class="glacier-ad unrendered top content-module" data-ad-type="top" data-viewport="tablet desktop" id="top"></div>
# <div class="two-column-page-content">
# <div class="page-column-1">
# <div class="page-content content-module">
# <a class="cur-con-weather-card card-module content-module lbar-panel" href="/en/kz/almaty/222191/current-weather/222191">
# <div class="cur-con-weather-card__body">
# <div class="cur-con-weather-card__panel">
# <h2 class="cur-con-weather-card__title">
# 				Current Weather
# 			</h2>
# <p class="cur-con-weather-card__subtitle">
# 				12:12 PM
# 			</p>
# <div class="forecast-container">
# <svg class="weather-icon" data-src="/images/weathericons/1.svg" height="88" viewbox="0 0 288 288" width="88"><g fill="none" fill-rule="evenodd" stroke="#FF8700" stroke-width="9.6"><path d="M144 0v48M144 240v48M0 144h48M211.872 76.128l33.936-33.936M245.808 245.808l-33.936-33.936M76.128 76.128 42.192 42.192"></path><circle cx="144" cy="144" r="76.8"></circle><path d="m76.128 211.872-33.936 33.936M240 144h48"></path></g></svg>
# <div class="temp-container">
# <div class="temp">18°<span class="after-temp">C</span></div>
# <div class="real-feel">
# 						RealFeel®
# 						22°
# 					</div>
# </div>
# </div>
# </div>
# <div class="cur-con-weather-card__panel details-container">
# <div class="spaced-content detail">
# <span class="label">RealFeel Shade™</span>
# <span class="value">18°</span>
# </div>
# <div class="spaced-content detail">
# <span class="label">Air Quality</span>
# <span class="value" style="color: #FFC300">Fair</span>
# </div>
# <div class="spaced-content detail">
# <span class="label">Wind</span>
# <span class="value">NW 6 km/h</span>
# </div>
# <div class="spaced-content detail">
# <span class="label">Wind Gusts</span>
# <span class="value">15 km/h</span>
# </div>
# </div>
# </div>
# <div class="spaced-content">
# <span class="phrase">Sunny</span>
# <span class="cur-con-weather-card__cta">
# <span class="text">More Details</span>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </span>
# </div>
# </a>
# <div class="air-quality-card content-module" data-qa="airQualityCard">
# <h2 class="air-quality-card__header module-title">
# 		Current Air Quality
# 	</h2>
# <div class="air-quality-content">
# <div class="date-wrapper">
# <p class="day-of-week">Today</p>
# <p class="date">10/12</p>
# </div>
# <div class="content-wrapper">
# <div class="particle-chart">
# <div class="aq-particles"><div class="aq-number-wrapper">
# <div class="aq-number-container">
# <div class="aq-number">
# 						24
# 					</div>
# <div class="aq-unit">AQI</div>
# </div>
# </div>
# <svg class="air-quality-particles" height="180" width="180"><g class="particles active-particles"><circle cx="90" cy="27.5" key="1" r="2.3"></circle><circle cx="90" cy="15" key="2" r="2.3"></circle><circle cx="90" cy="2.5" key="3" r="2.3"></circle></g><g class="particles active-particles"><circle cx="102.19314512600802" cy="28.700919974798097" key="1" r="2.3"></circle><circle cx="104.63177415120961" cy="16.44110396975772" key="2" r="2.3"></circle><circle cx="107.07040317641122" cy="4.181287964717342" key="3" r="2.3"></circle></g><g class="particles active-particles"><circle cx="113.91771452281812" cy="32.25752921804458" key="1" r="2.3"></circle><circle cx="118.70125742738173" cy="20.709035061653495" key="2" r="2.3"></circle><circle cx="123.48480033194537" cy="9.160540905262408" key="3" r="2.3"></circle></g><g class="particles active-particles"><circle cx="124.72313956372514" cy="38.033149231090924" key="1" r="2.3"></circle><circle cx="131.66776747647015" cy="27.639779077309107" key="
arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="powered-by" href="https://air.plumelabs.com/air-quality-in-almaty-6p56?utm_source=accuweather&amp;utm_medium=current_aq_widget&amp;utm_campaign=#ae16">
# <h4 class="powered-by__content">
# <span>
# 							Learn more at
# 						</span>
# <img alt="Plumb Labs Logo" height="16px" src="/images/logos/plumb-labs-logo-blue.png"/>
# </h4>
# </a>
# </h3>
# </div>
# </div>
# <div class="tooltip aq-tooltip">
# <div class="icon-tooltip light"></div>
# <div class="tooltip-overlay">
# <div class="tooltip-header">
# <h2 class="tooltip-header__title">
# 				Current Air Quality
# 			</h2>
# <div class="icon-tooltip light"></div>
# </div>
# <h3 class="tooltip-content">
# 			Our current air quality index (AQI) provides information on the quality of air that you are breathing and its impact on your health. There are at least six different pollutants that we track that impact the cleanliness of air and your health.
# 		</h3>
# </div>
# </div>
# </div>
# </div>
# <div class="lifestyle-index-list unrendered content-module is-widget">
# <div class="lifestyle-index-list__header">
# <div class="index-list-title-wrapper">
# <div class="index-list-title spaced-content">
# <div>Health &amp; Activities</div>
# <a class="cta-link cta-header" href="/en/kz/almaty/222191/health-activities/222191"><span>See all</span><svg class="cta-arrow" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg></a>
# </div>
# </div>
# </div>
# <div class="lifestyle-index-list__cards">
# <div class="index-list-arrow prev-button"><svg class="arrow-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg></div>
# <div class="index-list-arrow next-button"><svg class="arrow-icon" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg></div>
# <div class="index-list-cards-container">
# <a class="index-list-card" data-index-slug="dust-dander" href="/en/kz/almaty/222191/allergies-weather/222191?name=dust-dander" style="--border-color:#dc250e">
# <div class="index-icon"><svg height="22" viewbox="0 0 24 24" width="22" xmlns="http://www.w3.org/2000/svg"><defs><filter id="dsvg"><fecolormatrix in="SourceGraphic" values="0 0 0 0 0.000000 0 0 0 0 0.000000 0 0 0 0 0.000000 0 0 0 1.000000 0"></fecolormatrix></filter></defs><g fill="none" fill-rule="evenodd" filter="url(#dsvg)" transform="translate(0 -1)"><g stroke="#FFF"><path d="M2 9a6 6 0 1 1 12 0A6 6 0 0 1 2 9h0z" stroke-linecap="round" stroke-linejoin="round"></path><path d="M19.104 3.396 16.5 6" stroke-linecap="square"></path><path d="M14 19a4 4 0 1 1 8 0 4 4 0 0 1-8 0h0z" stroke-linecap="round" stroke-linejoin="round"></path><path d="m5.135 18.176-2.811 2.812" stroke-linecap="square"></path><path d="M18 9a2 2 0 1 1 3.999-.001A2 2 0 0 1 18 9h0z" stroke-linecap="round" stroke-linejoin="round"></path><path d="m9.041 19.041 2.541 2.541" stroke-linecap="square"></path></g></g></svg></div>
# <div class="index-name">Dust &amp; Dander</div>
# <div class="index-status-color" style="background:#dc250e"></div>
# <div class="index-status-text">Very High</div>
# <div class="index-status-phrase">The risk of dust and dander allergy symptoms is very high. When dusting, use a microfiber cloth to help hold dust instead of pushing it around.</div>
# </a>
# <a class="index-list-card" data-index-slug="arthritis" href="/en/kz/almaty/222191/arthritis-weather/222191" style="--border-color:#93c701">
# <div class="index-icon"><svg height="22" viewbox="0 0 24 24" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M21.586 4H2.414C1.065 4 0 5.094 0 6.48v12.04C0 19.905 1.065 21 2.414 21h19.172C22.935 21 24 19.906 24 18.52V6.48C24 5.168 22.935 4 21.586 4zm1.349 14.592c0 .73-.64 1.387-1.35 1.387H2.416c-.71 0-1.35-.657-1.35-1.387V6.481c0-.73.64-1.387 1.35-1.387h19.17c.71 0 1.35.657 1.35 1.387v12.111z"></path><path d="M13.917 6.627h-3.905v3.867H6.249v4.012h3.763v3.94h3.905v-3.94h3.834v-4.012h-3.834z"></path></svg></div>
# <div class="index-name">Arthritis</div>
# <div class="index-status-color" style="background:#93c701"></div>
# <div class="index-status-text">Low</div>
# <div class="index-status-phrase">The risk of experiencing weather-related arthritis pain is low.</div>
# </a>
# <a class="index-list-card" data-index-slug="sinus" href="/en/kz/almaty/222191/sinus-weather/222191" style="--border-color:#93c701">
# <div class="index-icon"><svg height="22" viewbox="18.4 0 23.2 28" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M41.1 15.1c-.6-1-2-3.6-2.1-5C39 8.7 38 0 28.9 0S18.4 7.5 18.4 12s4.5 4.8 4.5 7.2V28h5.3c-.2-1.8-.5-6.2.2-9.8.6-3.1 2.3-9.2 7.6-9.4.4 0 .8.3.8.7 0 .4-.3.8-.7.8-1.8.1-3.1 1.1-4.1 2.5.1 0 .2-.1.4-.1 5.6-.8 6.7 1.5 6.8 1.7.2.4 0 .8-.4 1-.4.2-.8 0-1-.4 0-.1-.9-1.5-5.2-.9-1.2.2-2 1.5-2.4 3.3 2.4-.9 6.3.3 6.7.5.4.1.6.6.5.9-.1.4-.6.6-.9.5-1.2-.4-4.7-1.2-6.1-.3-.3.2-.5.5-.6.9-.3 2.9-.2 6.1 0 8h4v-4.4c0-1.1 1.1-.8 1.6-.8H37c1.2 0 2.2-.7 2.2-1.8V17h2c.6.1.5-.9-.1-1.9z"></path></svg></div>
# <div class="index-name">Sinus Pressure</div>
# <div class="index-status-color" style="background:#93c701"></div>
# <div class="index-status-text">Low</div>
# <div class="index-status-phrase">The risk of weather-related sinus pressure is low.</div>
# </a>
# <a class="index-list-card" data-index-slug="common-cold" href="/en/kz/almaty/222191/cold-flu-weather/222191?name=common-cold" style="--border-color:#93c701">
# <div class="index-icon"><svg height="22" viewbox="0 0 24 24" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M24 8.333v-.186c0-.062-.062-.062-.062-.062l-.062-.062-.062-.062h-.062c-.062 0-.124-.062-.186-.062h-7.008C15.194 4.8 18.605.83 18.605.767c.186-.124.186-.372.062-.558-.124-.186-.31-.248-.558-.186-.062 0-3.411 1.179-5.148 1.613C10.915 2.132 8.744.147 8.744.147 8.62.023 8.496.023 8.31.023c-.124.062-.248.124-.31.248-1.178 2.853-.248 5.892.496 7.628h-.682L.248 10.318s-.062 0-.062.062l-.062.062-.062.062-.062.062v6.263a.49.49 0 0 0 .496.497h18.915c.062 0 .124 0 .186-.062 0 0 .062
.2zM47.6 15.7c-.5.1-1.1.2-1.7.2.1 0 .1.1.1.1-.3.4-2.2 1.2-5.6 1.2 1.3.2 2.7.3 3.9.3 1 0 2.2-.1 3.4-.3V16c-.1-.1-.1-.2-.1-.3z"></path><path d="M36.5 15c.5-.1 1.1-.2 1.7-.2-.1 0-.1-.1-.1-.1v-1.5c-.5 0-1.1.1-1.6.2v1.3c-.1.1-.1.2 0 .3z"></path></svg></div>
# <div class="index-name">Flu</div>
# <div class="index-status-color" style="background:#93c701"></div>
# <div class="index-status-text">Low</div>
# <div class="index-status-phrase">The risk of catching the flu is low.</div>
# </a>
# <a class="index-list-card" data-index-slug="migraine" href="/en/kz/almaty/222191/migraine-weather/222191" style="--border-color:#93c701">
# <div class="index-icon"><svg height="22" viewbox="18.4 0 23.2 28" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M41.1 15.1c-.6-1-2-3.6-2.1-5C39 8.7 38 0 28.9 0S18.4 7.5 18.4 12s4.5 4.8 4.5 7.2V28h10.9v-4.4c0-1.1 1.1-.8 1.6-.8H37c1.2 0 2.2-.7 2.2-1.8v-3.9h2c.6 0 .5-1-.1-2zM22.4 7.8c0-2.4 2.4-4.4 5.5-4.7l-2.7 5.5h4.6l-2.3 3.9c-2.9-.5-5.1-2.4-5.1-4.7zm6.8 4.7L32.4 7h-4.8l2-4c3.1.3 5.5 2.3 5.5 4.7 0 2.6-2.6 4.7-5.9 4.8z"></path></svg></div>
# <div class="index-name">Migraine</div>
# <div class="index-status-color" style="background:#93c701"></div>
# <div class="index-status-text">Low</div>
# <div class="index-status-phrase">The risk of suffering from a weather-related migraine is low.</div>
# </a>
# <a class="index-list-card" data-index-slug="asthma" href="/en/kz/almaty/222191/asthma-weather/222191" style="--border-color:#93c701">
# <div class="index-icon"><svg height="22" viewbox="12.32 0 35.4 28" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M26.6 17.3c-.4 0-.7.4-.7.8.2 2 .2 5.5-.6 6.5-.6.7-3.4 1.8-6.1 1.8-1.5 0-3.5-.3-4.8-1.8-.8-1-.7-3.3.3-6.3 1.7-5 5.4-10.3 7.6-10.9.3 0 2 0 2.9.8.4.3.5.8.5 1.3 0 .4.3.8.8.8s.8-.3.8-.8c0-1-.3-1.8-1-2.4C24.7 5.8 22.2 6 22 6h-.1c-3 .7-7 6.8-8.7 11.9-.8 2.5-1.5 5.8 0 7.7 1.3 1.5 3.3 2.3 5.9 2.3 2.9 0 6.2-1.1 7.3-2.3 1.5-1.8 1-7 1-7.6 0-.4-.4-.7-.8-.7z"></path><path d="M21.8 11c-.3-.2-.8-.1-1 .2-.2.3-.1.8.2 1l3.2 2.1-4.7 2.2c-.4.2-.5.6-.4 1 .1.3.4.4.7.4.1 0 .2 0 .3-.1l2.6-1.2-1.4 4c-.1.4.1.8.5 1h.2c.3 0 .6-.2.7-.5l1.9-5.4 5.3-2.5 5.3 2.5 1.9 5.4c.1.3.4.5.7.5h.2c.4-.1.6-.6.5-1l-1.4-4 2.6 1.2c.1 0 .2.1.3.1.3 0 .6-.2.7-.4.2-.4 0-.8-.4-1l-4.7-
# <div class="index-name">Fishing</div>
# <div class="index-status-color" style="background:#93c701"></div>
# <div class="index-status-text">Great</div>
# <div class="index-status-phrase">Fishing conditions are great. Find an area with less boat or human activity to avoid areas where fish are hiding.</div>
# </a>
# <a class="index-list-card" data-index-slug="running" href="/en/kz/almaty/222191/running-weather/222191" style="--border-color:#93c701">
# <div class="index-icon"><svg height="22" viewbox="8 3.2 43.97 21.4" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M51.5 17.8c.5-1 .6-1.8.3-2.4-.8-1.5-2.7-1.7-5.5-1.9-2.2-.2-5-.3-8.4-1.2-6-1.5-10.2-6.6-10.2-6.6l-.3-.4-.4.1c-8 1.7-13-1.7-13.1-1.8l-.6-.4L11 6.9C9 10 8.2 19.7 8.1 20.1l-.1.6.6.1c.2 0 4.6 1.1 7.9 1.2h2.1c2.2 0 4.6-.1 13 1.9 2.1.5 4.1.7 6 .7 6.3 0 10.8-2.6 13-5.6.4-.3.6-.7.9-1.2zM13.6 5.4c1.7.9 6.4 3 13.1 1.7.1.1.1.2.2.2-5.8 2.1-11.8-.2-13.8-1.2l.5-.7zm-1.4 2.3.2-.3c1.4.7 5.2 2.3 9.5 2.3 2 0 4.1-.3 6.3-1.2.2.2.5.4.7.6l-2.7 2.2c-.3.3-.4.7-.1 1.1.1.2.4.3.6.3s.3-.1.5-.2l3-2.4c.6.5 1.3.9 2 1.4l-2.1 2.2c-.3.3-.3.8 0 1.1.1.1.3.2.5.2s.4-.1.5-.2l2.3-2.5c.9.5 2 .9 3 1.3l-1.6 2.1c-.3.3-.2.8.1 1.1.1.1.3.2.5.2s.4-.1.6-.3l2-2.6c3.3.8 6.1 1 8.2 1.1 2.3.2 3.9.3 4.3 1 0 .1 0 .5-.3 1-.8.7-6.3 5-13.5 3.3-3.6-.9-6.3-.9-8.1-.1-.8.4-1.3.9-1.6 1.3-1.5-.3-2.7-.5-3.7-.6-.3-.9-2.6-5.6-13.1-5.6.4-3.1 1.1-6.4 2-7.8zm6.4 13h-2c-2.4-.1-5.6-.8-7-1.1.1-.8.2-1.7.3-2.8 7.7-.1 10.6 2.5 11.5 3.9-.7 0-1.3-.1-1.8-.1-.3 0-.6.1-1 .1zM32 22.6c-1.2-.3-2.2-.5-3.2-.7.8-.6 2.9-1.2 7.5-.1 3.7.9 6.9.4 9.5-.5-2.8 1.5-7.3 2.8-13.8 1.3z"></path></svg></div>
# <div class="index-name">Running</div>
# <div class="index-status-color" style="background:#93c701"></div>
# <div class="index-status-text">Ideal</div>
# <div class="index-status-phrase">Conditions for running are ideal.</div>
# </a>
# <a class="index-list-card" data-index-slug="golf" href="/en/kz/almaty/222191/golf-weather/222191" style="--border-color:#93c701">
# <div class="index-icon"><svg height="22" viewbox="10.2 1.86 39.7 24.24" width="22" xmlns="http://www.w3.org/2000/svg"><path d="
.3 2.2 5.2 2.2 1.8 0 3.5-.6 4.8-1.8 1.3-1 2.1-2.4 2.5-4l-7.8-.7c-.2 0-.3-.2-.3-.3v-.1l3.4-7.5c-.8-.3-1.6-.5-2.5-.5zm9 7.8 1.3.1-4.2-11.5-1.5 3.4c2.9 1.7 4.4 4.3 4.4 7.7v.3zm-7.7-.8 6.1.6V19c.1-2.6-1.3-5-3.5-6.3l-2.6 5.8zm10.2-.1 8.4-10.1-.6-1.7H24.8l4.3 11.8z"></path></svg></div>
# <div class="index-name">Biking &amp; Cycling</div>
# <div class="index-status-color" style="background:#93c701"></div>
# <div class="index-status-text">Ideal</div>
# <div class="index-status-phrase">Conditions for cycling are ideal.</div>
# </a>
# <a class="index-list-card" data-index-slug="sun-sand" href="/en/kz/almaty/222191/sun-sand-weather/222191" style="--border-color:#93c701">
# <div class="index-icon"><svg height="22" viewbox="7.6 6.4 45.1 15.4" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M26.2 8.8s-11.8-2.9-15.3 0c0 0-1.2 13.2 8.1 11.5 9.2-1.7 7-2.7 8.3-7.8s-1.1-3.7-1.1-3.7zM34.1 8.8s11.8-2.9 15.3 0c0 0 1.2 13.2-8.1 11.5-9.2-1.7-7-2.7-8.3-7.8s1.1-3.7 1.1-3.7z"></path><path d="M51.9 7.8c-.3-.1-6.4-1.4-11.2-1.4-1.7 0-3.1.2-4 .5-3.9 1.5-6.6 1.6-6.7 1.6s-2.8-.2-6.7-1.6c-.9-.4-2.3-.5-4-.5-4.8 0-10.9 1.4-11.2 1.4l-.5.1v.5l.3 3 .2.6.6-.1H9c.7 0 1.1.4 1.2 1.2.3 2.4 1 5.8 2.8 7.4 1.4 1.2 4.7 1.3 5.7 1.3 2.8 0 5.4-.5 6.8-1.4h.1v-.1c.8-.9 1.8-3.9 2.4-6.2.4-1.8 2.1-1.9 2.2-1.9s1.8.1 2.2 1.9c.5 2.3 1.6 5.3 2.4 6.2v.1h.1c1.4.9 3.9 1.4 6.8 1.4 1 0 4.3-.1 5.7-1.3 1.8-1.6 2.4-5 2.8-7.4.1-.8.5-1.2 1.2-1.2h.3l.6.1.1-.6.3-3v-.5l-.8-.1zm-27.2 9.9c-.8 1.1-2.5 2-5.6 2s-5.5-.6-6.1-1.7c-.6-1-1.6-5.6-1.1-6.6.5-1.1 2.4-3.2 6-3.2 3.7 0 7.6 1 8.3 2.1.7 1.3-.6 6.3-1.5 7.4zM47 18c-.6 1-3 1.7-6.1 1.7-3.1 0-4.8-.9-5.6-2-.8-1.1-2.2-6.2-1.5-7.4.7-1.2 4.6-2.1 8.3-2.1 3.7 0 5.5 2.1 6 3.2S47.5 17 47 18z"></path></svg></div>
# <div class="index-name">Beach &amp; Pool</div>
# <div class="index-status-color" style="background:#93c701"></div>
# <div class="index-status-text">Great</div>
# <div class="index-status-phrase">Conditions for a day at the beach or pool are great. Remember to stay hydrated.</div>
# </a>
# <a class="index-list-card" data-index-slug="astronomy" href="/en/kz/almaty/222191/astronomy-weather/222191" style="--border-color:#93c701">
# ...
# </a>
# <a class="social-link" data-gacategory="Twitter" data-galink="https://twitter.com/BreakingWeather" data-gatype="social" href="https://twitter.com/BreakingWeather" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/twitter.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="nonzero"><path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#1DA1F3"></path><path d="M26.904 14.316c.012.183.012.376.012.57 0 5.774-4.294 12.448-12.14 12.448a11.96 11.96 0 0 1-6.538-1.96c.33.046.672.058 1.014.058a8.424 8.424 0 0 0 5.296-1.868c-1.868-.034-3.44-1.298-3.987-3.04.262.056.524.079.798.079.387 0 .763-.057 1.127-.16-1.947-.398-3.428-2.163-3.428-4.293v-.057c.581.33 1.23.524 1.936.547a4.417 4.417 0 0 1-1.902-3.645c0-.797.205-1.549.581-2.198 2.107 2.654 5.25 4.385 8.792 4.567a4.717 4.717 0 0 1-.114-.99c0-2.415 1.914-4.374 4.26-4.374 1.23 0 2.335.535 3.109 1.378a8.26 8.26 0 0 0 2.71-1.06 4.3 4.3 0 0 1-1.879 2.415A8.4 8.4 0 0 0 29 12.05c-.535.877-1.264 1.64-2.096 2.266Z" fill="#FFF"></path></g></svg>
# </a>
# <a class="social-link" data-gacategory="TV" data-galink="https://getaccuweather.tv" data-gatype="outbound" href="https://getaccuweather.tv/?utm_source=adc&amp;utm_medium=icon&amp;utm_campaign=footer" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/tv.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="evenodd"><circle cx="18" cy="18" fill="#F05514" r="18"></circle><g fill="#FFF"><path d="M10.933 15.533H7.88v-2.08h8.44v2.08h-3.04v8.6h-2.347zM17.52 13.453h2.68l2.64 7h.027l2.68-7h2.52l-4.4 10.68h-1.88z"></path></g></g></svg>
# </a>
# </div>
# </div>
# </div>, <div class="footer-content-category-wrapper">
# <div class="footer-content-category-header">More</div>
# <div class="footer-category-section">
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="AccuWeather Shop" href="https://www.accuweather.com/shop" target="_blank">
# 			AccuWeather Shop
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="AccuWeather Ready" href="/en/accuweather-ready">
# 			AccuWeather Ready
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Business" href="/en/business">
# 			Business
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Health" href="/en/health-wellness">
# 			Health
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Hurricane" href="/en/hurricane">
# 			Hurricane
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Leisure and Recreation" href="/en/leisure-recreation">
# 			Leisure and Recreation
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Severe Weather" href="/en/kz/severe-weather">
# 			Severe Weather
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Space and Astronomy" href="/en/space-news">
# 			Space and Astronomy
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Sports" href="/en/sports">
# 			Sports
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Travel" href="/en/travel">
# 			Travel
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Weather News" href="/en/weather-news">
# 			Weather News
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Weather Blogs" href="/en/weather-blogs">
# 			Weather Blogs
# 		</a>
# </div>
# <div class="footer-social footer-social-tablet">
# <a class="social-link" data-gacategory="Downloads" data-galink="https://downloads.accuweather.com/" data-gatype="outbound" href="https://downloads.accuweather.com/" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons
# </a>
# <a class="social-link" data-gacategory="TV" data-galink="https://getaccuweather.tv" data-gatype="outbound" href="https://getaccuweather.tv/?utm_source=adc&amp;utm_medium=icon&amp;utm_campaign=footer" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/tv.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="evenodd"><circle cx="18" cy="18" fill="#F05514" r="18"></circle><g fill="#FFF"><path d="M10.933 15.533H7.88v-2.08h8.44v2.08h-3.04v8.6h-2.347zM17.52 13.453h2.68l2.64 7h.027l2.68-7h2.52l-4.4 10.68h-1.88z"></path></g></g></svg>
# </a>
# </div>
# </div>, <div class="footer-content-category-header">More</div>, <div class="footer-category-section">
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="AccuWeather Shop" href="https://www.accuweather.com/shop" target="_blank">
# 			AccuWeather Shop
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="AccuWeather Ready" href="/en/accuweather-ready">
# 			AccuWeather Ready
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Business" href="/en/business">
# 			Business
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Health" href="/en/health-wellness">
# 			Health
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Hurricane" href="/en/hurricane">
# 			Hurricane
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Leisure and Recreation" href="/en/leisure-recreation">
# 			Leisure and Recreation
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Severe Weather" href="/en/kz/severe-weather">
# 			Severe Weather
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Space and Astronomy" href="/en/space-news">
# 			Space and Astronomy
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Sports" href="/en/sports">
# 			Sports
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Travel" href="/en/travel">
# 			Travel
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Weather News" href="/en/weather-news">
# 			Weather News
# 		</a>
# <a class="footer-category-section-link" data-gacategory="More" data-gatext="Weather Blogs" href="/en/weather-blogs">
# 			Weather Blogs
# 		</a>
# </div>, <div class="footer-social footer-social-tablet">
# <a class="social-link" data-gacategory="Downloads" data-galink="https://downloads.accuweather.com/" data-gatype="outbound" href="https://downloads.accuweather.com/" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons/downloads.svg" height="32" viewbox="0 0 36 36" width="32"><g fill="none" fill-rule="evenodd"><path d="M18 0C8.053 0 0 8.053 0 18s8.053 18 18 18 18-8.053 18-18S27.947 0 18 0Z" fill="#EE5723"></path><path d="M12.88 12.947a7.243 7.243 0 0 1 10.24 0c2.813 2.826 2.827 7.413 0 10.226-2.827 2.827-7.413 2.827-10.227 0-2.826-2.813-2.826-7.4-.013-10.226ZM18 9.907c-4.467 0-8.107 3.64-8.107 8.106 0 4.467 3.64 8.107 8.107 8.107 4.467 0 8.107-3.64 8.107-8.107 0-4.48-3.64-8.106-8.107-8.106Zm10.12 2.213-3.52-.76-.773-3.507L20.4 8.947l-2.427-2.654L15.56 8.96l-3.427-1.08-.76 3.52-3.506.773L8.973 15.6 6.32 18.027l2.667 2.413-1.08 3.427 3.52.76.773 3.506 3.427-1.093 2.426 2.653 2.414-2.666 3.426 1.08.76-3.52 3.507-.787-1.107-3.427 2.654-2.426-2.667-2.414 1.08-3.413Z" fill="#FFF"></path></g></svg>
# </a>
# <a class="social-link" data-gacategory="Facebook" data-galink="https://www.facebook.com/AccuWeather" data-gatype="social" href="https://www.facebook.com/AccuWeather" rel="noopener noreferrer" target="_blank">
# <svg alt="Social Icon" class="social-icon" data-src="/images/socialicons
# </div>, <div class="footer-legalese">
# <div class="footer-copyright">
# <span>
# 			© 2021 AccuWeather, Inc. "AccuWeather" and sun design are registered trademarks of AccuWeather, Inc. All Rights Reserved.
# 		</span>
# </div>
# <div class="footer-terms" id="footer-terms">
# <a data-ga="Terms of usage" href="/en/legal" target="_blank">
# 			Terms of Use
# 		</a>
# 		|
# 		<a data-ga="Privacy Policy" href="/en/privacy" target="_blank">
# 			Privacy Policy
# 		</a>
# 		|
# 		<a data-ga="Cookie Policy" href="/en/cookiepolicy" target="_blank">
# 			Cookie Policy
# 		</a>
# 		|
# 		<a data-ga="TAG Disclosure" href="/en/tag-publisher-sourcing-disclosure" target="_blank">
# 			TAG Disclosure
# 		</a>
# </div>
# </div>, <div class="footer-copyright">
# <span>
# 			© 2021 AccuWeather, Inc. "AccuWeather" and sun design are registered trademarks of AccuWeather, Inc. All Rights Reserved.
# 		</span>
# </div>, <div class="footer-terms" id="footer-terms">
# <a data-ga="Terms of usage" href="/en/legal" target="_blank">
# 			Terms of Use
# 		</a>
# 		|
# 		<a data-ga="Privacy Policy" href="/en/privacy" target="_blank">
# 			Privacy Policy
# 		</a>
# 		|
# 		<a data-ga="Cookie Policy" href="/en/cookiepolicy" target="_blank">
# 			Cookie Policy
# 		</a>
# 		|
# 		<a data-ga="TAG Disclosure" href="/en/tag-publisher-sourcing-disclosure" target="_blank">
# 			TAG Disclosure
# 		</a>
# </div>, <div class="glacier-ad unrendered oop" data-ad-type="oop" data-viewport="" id="oop"></div>, <div class="glacier-ad unrendered interstitial" data-ad-type="interstitial" data-viewport="" id="interstitial"></div>, <div class="privacy-policy-banner" data-banner-delay="0" data-banner-order="0" id="privacy-policy-banner">
# <div class="banner-body">
# <p>
# 				We have updated our <a href="/en/privacy" id="privacy-policy-banner-privacy-link" target="_blank">Privacy Policy</a> and <a href="/en/cookiepolicy" id="privacy-policy-banner-cookie-policy-link" target="_blank">Cookie Policy</a>.
# 			</p>
# <div class="banner-button policy-accept">I Understand</div>
# </div>
# </div>, <div class="banner-body">
# <p>
# 				We have updated our <a href="/en/privacy" id="privacy-policy-banner-privacy-link" target="_blank">Privacy Policy</a> and <a href="/en/cookiepolicy" id="privacy-policy-banner-cookie-policy-link" target="_blank">Cookie Policy</a>.
# 			</p>
# <div class="banner-button policy-accept">I Understand</div>
# </div>, <div class="banner-button policy-accept">I Understand</div>, <div class="feedback-banner hide-mobile" id="feedback-banner">
# <a class="feedback-banner-link" href="https://corporate.accuweather.com/company/contact/">
# <span>FEEDBACK</span>
# <svg class="icon-plus icon-plus" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd" stroke="#F05514" stroke-linecap="square" stroke-width="2">
# <path d="M9 0v18M0 9h18"></path>
# </g>
# </svg>
# </a>
# </div>]

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.accuweather.com/en/kz/almaty/222191/weather-forecast/222191"
headers = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36"}

resp = requests.get(url, headers = headers)

soup = BeautifulSoup(resp.content)
print(soup.find_all("div", class_="temp")[0].text)
# Out:
# 17°C
