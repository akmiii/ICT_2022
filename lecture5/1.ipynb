# %%
import requests
print(requests.__version__)
# Out:
# 2.28.1

# %%
url = "https://www.dior.com/en_int"
resp = requests.get(url)
print(resp.content)
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><script type="text/javascript" src="/couture-catalog-assets/_next/static/ruxitagentjs_ICA27Vfhjqrux_10249220905100923.js" data-dtconfig="rid=RID_-1303522183|rpid=831776036|domain=dior.com|reportUrl=/couture-catalog-assets/_next/static/rb_bf29769wnv|app=153d60cbda76cc08|rcdec=1209600000|featureHash=ICA27Vfhjqrux|vcv=2|rdnt=0|uxrgce=1|bp=3|srmcrv=10|cuc=50cv595i|mel=100000|dpvc=1|md=mdcc1=a#account ^rb div.generic-section__subsections ^rb div ^rb span.contact-information-read__email|ssv=4|lastModification=1664908487220|dtVersion=10249220905100923|srmcrl=1|tp=500,50,0,1|uxdcw=1500|agentUri=/couture-catalog-assets/_next/static/ruxitagentjs_ICA27Vfhjqrux_10249220905100923.js"></script><script>\n        window.dataLayer = window.dataLayer || [];\n\n        var dataLayerWithUemail = {"page":"/en_int","pageType":"ONEDIOR_PreHome","univers":"ONEDIOR","subUniverse":"","country":"in
# ...

# %%
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36', 'Accept-Language' : 'en-GB,en;q=0.5'}
url = "https://api-fashion.dior.com/couture/var/dior/storage/images/29895128/71-int-EN/cdc-dispatch13_1440_1200.jpg"
resp = requests.get(url, headers = headers)
print(resp.content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x01 \x01 \x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\t\xff\xc4\x00]\x10\x00\x02\x01\x02\x04\x04\x03\x04\x05\x04\x0b\x0c\x06\t\x04\x03\x00\x01\x11\x02\x03\x04\x05!1\x06\x12AQ\x07aq\x08\x13"\x81\x142\x91\xa1\xb1\x15#r\xc1\x16\x17$3BRb\x82\x92\xb2\xd1\x18%&4CDSTs\x
# ...

# %%
with open(r"C:\Users\Акмира\OneDrive\Документы\GitHub\ICT_2022\lecture5\dior.jpg", 'wb') as file:
    file.write(resp.content)

# %%
import requests
from datetime import datetime


origin = datetime(1970, 1, 1)
begin = datetime(2002, 1, 5)

delta = begin - origin
delta = delta.total_seconds()

url = "https://query1.finance.yahoo.com/v7/finance/download/MRNA"
params = {'period1' : str(int(delta)), 'period2' : '1664914851', 'interval' : '1d', 'events' : 'history', 'includeAdjustedClose' : 'true'}
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36'}

resp = requests.get(url, headers = headers)
print(resp.content)
# Out:
# b'Date,Open,High,Low,Close,Adj Close,Volume\n2022-10-05,122.400002,126.739998,121.610001,125.620003,125.620003,2275200'
