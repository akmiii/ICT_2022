# %%
import pandas as pd

df_origin = pd.read_csv(r"airbus_price.csv")
print(df_origin)

# df = df_origin[df_origin['Name'] == 'GOOGL']
# df = df.reset_index(drop = True)
# print(df)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2001-09-03  19.040001  19.240000  18.920000  18.990000  12.628183
# 1     2001-09-04  19.379999  19.940001  19.059999  19.940001  13.259927
# 2     2001-09-05  19.700001  19.930000  19.670000  19.700001  13.100326
# 3     2001-09-06  19.549999  19.700001  19.059999  19.059999  12.674736
# 4     2001-09-07  19.150000  19.350000  18.020000  18.110001  12.042991
# ...          ...        ...        ...        ...        ...        ...
# 5421  2022-10-10  91.800003  93.559998  91.580002  93.010002  93.010002
# 5422  2022-10-11  92.709999  94.199997  92.360001  93.930000  93.930000
# 5423  2022-10-12  94.000000  94.419998  92.480003  93.250000  93.250000
# 5424  2022-10-13  93.510002  97.430000  93.040001  96.900002  96.900002
# 5425  2022-10-14  98.720001  99.339996  96.260002  96.589996  96.589996
#
#          Volume
# 0      322507.0
# 1     2124573.0
# 2     1135245.0
# 3     1730852.0
# ...

# %%
import datetime
df_small = df_origin[df_origin['Date'] > "2022-08-12"]

# %%
import matplotlib.pyplot as plt

df_origin.plot(x = 'Date', y = 'Volume')
df_small.plot(x = 'Date', y = 'Volume')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df_origin.plot(kind = 'scatter', x = 'Open', y = 'Volume')
df_small.plot(kind = 'scatter', x = 'Open', y = 'Volume')
# Out:
# c:\Users\Акмира\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='Open', ylabel='Volume'>

# %%
df2 = df_origin[df_origin['Date'] > "2022-08-12"].copy()

# %%
perc = []
for index, line in df_origin.iterrows(): #or make copy: df_small = df_origin[df_origin['Date'] > "2022-08-12"].copy()
    if index == 0:
        perc.append(0)
    else:
        perc.append((line['Open'] - df_origin.loc[index-1, 'Open']) / line['Open'] * 100)

df_origin['Perc'] = perc

print(df_origin)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2001-09-03  19.040001  19.240000  18.920000  18.990000  12.628183
# 1     2001-09-04  19.379999  19.940001  19.059999  19.940001  13.259927
# 2     2001-09-05  19.700001  19.930000  19.670000  19.700001  13.100326
# 3     2001-09-06  19.549999  19.700001  19.059999  19.059999  12.674736
# 4     2001-09-07  19.150000  19.350000  18.020000  18.110001  12.042991
# ...          ...        ...        ...        ...        ...        ...
# 5421  2022-10-10  91.800003  93.559998  91.580002  93.010002  93.010002
# 5422  2022-10-11  92.709999  94.199997  92.360001  93.930000  93.930000
# 5423  2022-10-12  94.000000  94.419998  92.480003  93.250000  93.250000
# 5424  2022-10-13  93.510002  97.430000  93.040001  96.900002  96.900002
# 5425  2022-10-14  98.720001  99.339996  96.260002  96.589996  96.589996
#
#          Volume      Perc
# 0      322507.0  0.000000
# 1     2124573.0  1.754376
# ...

# %%
col = ['Open', 'Close', 'High', 'Low', 'Volume']

for i in col:
for index, line in df2.iterrows(): 
    if index == 0:
        perc_op.append(0)
    else:
        perc_op.append((line['Open'] - df2.loc[index-1, 'Open']) / line['Open'] * 100)


df2['Perc_Open'] = perc_op
# df2['Perc_Close'] = perc_cl
# df2['Perc_Volume'] = vol

print(df2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Акмира\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\Акмира\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Акмира\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 5380
#
# ...
